# %%
import pickle
import matplotlib.pyplot as plt 
import  numpy as np

# %%
with open('flower_history_gru.pkl', 'rb') as f:
    history_gru = pickle.load(f)

# %%
with open('flower_history_rnn.pkl', 'rb') as f:
    history_rnn= pickle.load(f)

# %%
with open('flower_history_lstm.pkl', 'rb') as f:
    history_lstm= pickle.load(f)

# %%
with open('flower_history_lstm_deep.pkl', 'rb') as f:
    history_lstm_deep= pickle.load(f)

# %%
with open('flower_history_stgode.pkl', 'rb') as f:
    history_stgode= pickle.load(f)

# %%
NUM_CLIENTS = 10
rounds = 10
x =  []
y = [[] for i in history.metrics_distributed['client_metrics'][0][1]['valid_rmse']]
for client_metrics in history.metrics_distributed['client_metrics']:
    x.append(client_metrics[0])
    for idx, client_loss in enumerate(client_metrics[1]['valid_rmse']):
        y[idx].append(client_loss)


plt.figure(figsize=(20, 12), dpi = 150)
ax = plt.axes()

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

for client_num, loss_ in enumerate(y):
    print(client_num)
    plt.plot(x, loss_, label='Val RMSE of c: '+str(client_num))
plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.legend()
plt.title('Validation Curve for RMSE (individual client), c = '+str(NUM_CLIENTS), fontsize = 24)

#plt.show()
plt.legend(fontsize=14)
plt.savefig(f'individual_val_average_RMSE_rounds_{rounds}_c_{NUM_CLIENTS}.png', bbox_inches='tight')
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
np.log(y)
# Out:
# array([5.09190978, 5.06617758, 4.59853576, 4.10788073, 3.87436501,
#        3.74722885, 3.78547557, 3.7777726 , 3.71300417, 3.70801784])

# %%
history = history_gru
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])


plt.figure(figsize=(20, 12), dpi = 150)
ax = plt.axes()

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

plt.plot(x, y, label='GRU Average RMSE')

history = history_rnn
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])

plt.plot(x, y, label='RNN Average RMSE')

history = history_lstm
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])

plt.plot(x, y, label='LSTM Average RMSE')

history = history_lstm_deep
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])

plt.plot(x, y, label='LSTM Deep Average RMSE')

history = history_stgode
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])

plt.plot(x, y, label='STGODE Average RMSE')

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE c='+str(NUM_CLIENTS), fontsize=20)
#plt.show()
plt.legend(fontsize=14, loc='lower right')
plt.savefig(f'average_val_RMSE_rounds_{rounds}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

# %%
history = history_gru
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])


plt.figure(figsize=(20, 12), dpi = 150)
ax = plt.axes()

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

plt.plot(x, y, label='GRU Average RMSE')

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE c='+str(NUM_CLIENTS), fontsize=20)
#plt.show()
plt.legend(fontsize=14, loc='lower right')
plt.savefig(f'average_val_RMSE_rounds_{rounds}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

# %%
history = history_lstm
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])


plt.figure(figsize=(20, 12), dpi = 150)
ax = plt.axes()

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

plt.plot(x, y, label='GRU Average RMSE')

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE c='+str(NUM_CLIENTS), fontsize=20)
#plt.show()
plt.legend(fontsize=14, loc='lower right')
plt.savefig(f'average_val_RMSE_rounds_{rounds}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

# %%
history = history_stgode
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])


plt.figure(figsize=(20, 12), dpi = 150)
ax = plt.axes()

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

plt.plot(x, y, label='GRU Average RMSE')

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE c='+str(NUM_CLIENTS), fontsize=20)
#plt.show()
plt.legend(fontsize=14, loc='lower right')
plt.savefig(f'average_val_RMSE_rounds_{rounds}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

# %%
history = history_lstm_deep
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])


plt.figure(figsize=(20, 12), dpi = 150)
ax = plt.axes()

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

plt.plot(x, y, label='GRU Average RMSE')

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE c='+str(NUM_CLIENTS), fontsize=20)
#plt.show()
plt.legend(fontsize=14, loc='lower right')
plt.savefig(f'average_val_RMSE_rounds_{rounds}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

# %%
history = history_rnn
x, y = [], []
for average_metrics in history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])


plt.figure(figsize=(20, 12), dpi = 150)
ax = plt.axes()

ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)

plt.plot(x, y, label='GRU Average RMSE')

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE c='+str(NUM_CLIENTS), fontsize=20)
#plt.show()
plt.legend(fontsize=14, loc='lower right')
plt.savefig(f'average_val_RMSE_rounds_{rounds}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

# %%
gru = np.mean([i[1]['valid_rmse'] for i in history_gru.metrics_distributed['average_metrics']])
lstm = np.mean([i[1]['valid_rmse'] for i in history_lstm.metrics_distributed['average_metrics']])
stgode = np.mean([i[1]['valid_rmse'] for i in history_stgode.metrics_distributed['average_metrics']])
rnn = np.mean([i[1]['valid_rmse'] for i in history_rnn.metrics_distributed['average_metrics']])
lstm_deep  = np.mean([i[1]['valid_rmse'] for i in history_lstm_deep.metrics_distributed['average_metrics']])

# %%
bar_dict = {'lstm':lstm,  'rnn':rnn, 'gru':gru, 'lstm_deep':lstm_deep, 'stgode':stgode,}

# %%
courses = list(bar_dict.keys())
values = list(bar_dict.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color=['red', 'green', 'blue', 'pink'],
        width = 0.4)
 
plt.xlabel("Model Name")
plt.ylabel("Average Val RMSE")
plt.title("RMSE")
plt.show()

# %%
bar_dict
# Out:
# {'lstm': 8335.67204220503,
#  'rnn': 8318.569594350962,
#  'gru': 8341.023647085338,
#  'lstm_deep': 5606.476034029447,
#  'stgode': 74.15041173299153}

# %%
gru = np.mean([i[1]['valid_mae'] for i in history_gru.metrics_distributed['average_metrics']])
lstm = np.mean([i[1]['valid_mae'] for i in history_lstm.metrics_distributed['average_metrics']])
stgode = np.mean([i[1]['valid_mae'] for i in history_stgode.metrics_distributed['average_metrics']])
rnn = np.mean([i[1]['valid_mae'] for i in history_rnn.metrics_distributed['average_metrics']])
lstm_deep  = np.mean([i[1]['valid_mae'] for i in history_lstm_deep.metrics_distributed['average_metrics']])

# %%
bar_dict = {'lstm':lstm,  'rnn':rnn, 'gru':gru, 'lstm_deep':lstm_deep, 'stgode':stgode,}

# %%
bar_dict
# Out:
# {'lstm': 8317.031639560797,
#  'rnn': 8299.074346454327,
#  'gru': 8322.130008263219,
#  'lstm_deep': 5576.872619065504,
#  'stgode': 57.56299860636394}

# %%
gru = np.mean([i[1]['valid_mape'] for i in history_gru.metrics_distributed['average_metrics']])
lstm = np.mean([i[1]['valid_mape'] for i in history_lstm.metrics_distributed['average_metrics']])
stgode = np.mean([i[1]['valid_mape'] for i in history_stgode.metrics_distributed['average_metrics']])
rnn = np.mean([i[1]['valid_mape'] for i in history_rnn.metrics_distributed['average_metrics']])
lstm_deep  = np.mean([i[1]['valid_mape'] for i in history_lstm_deep.metrics_distributed['average_metrics']])

# %%
bar_dict = {'lstm':lstm,  'rnn':rnn, 'gru':gru, 'lstm_deep':lstm_deep, 'stgode':stgode,}
bar_dict
# Out:
# {'lstm': 8317.031639560797,
#  'rnn': 8299.074346454327,
#  'gru': 8322.130008263219,
#  'lstm_deep': 5576.872619065504,
#  'stgode': 130.2742576797803}
