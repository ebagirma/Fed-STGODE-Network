# %% [markdown]
# ## import libraries

# %%
# !pip3 install -U flwr-nightly
# !pip3 install -U flwr-nightly[simulation]
# !pip install torchdiffeq
# !pip install fastdtw
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flwr-nightly in /usr/local/lib/python3.9/dist-packages (1.5.0.dev20230421)
# Requirement already satisfied: grpcio!=1.52.0,<2.0.0,>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly) (1.53.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.19.0 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly) (3.20.3)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly) (0.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flwr-nightly[simulation] in /usr/local/lib/python3.9/dist-packages (1.5.0.dev20230421)
# Requirement already satisfied: grpcio!=1.52.0,<2.0.0,>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly[simulation]) (1.53.0)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly[simulation]) (1.24.3)
# Requirement already satisfied: protobuf<4.0.0,>=3.19.0 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly[simulation]) (3.20.3)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly[simulation]) (0.0.2)
# Requirement already satisfied: ray[default]<3.0.0,>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from flwr-nightly[simulation]) (2.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (2.27.1)
# Requirement already satisfied: virtualenv>=20.0.24 in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (20.22.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.3.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (8.1.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.0.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (3.11.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (4.3.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (23.1.0)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.7.0)
# Requirement already satisfied: aiohttp>=3.7 in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (3.8.4)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.11.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.10.7)
# Requirement already satisfied: gpustat>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.1)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.3.14)
# Requirement already satisfied: colorful in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.5.5)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (6.3.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.16.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp>=3.7->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.9.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp>=3.7->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp>=3.7->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp>=3.7->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (6.0.4)
# Requirement already satisfied: blessed>=1.17.1 in /usr/local/lib/python3.9/dist-packages (from gpustat>=1.0.0->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.20.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /usr/local/lib/python3.9/dist-packages (from gpustat>=1.0.0->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (11.525.112)
# Requirement already satisfied: psutil>=5.6.0 in /usr/local/lib/python3.9/dist-packages (from gpustat>=1.0.0->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (5.9.5)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.0.24->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=3.2 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.0.24->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (3.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.19.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (2.11.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.1.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (3.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.16.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.9/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.2.6)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.9/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (2.17.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (1.59.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr-nightly[simulation]) (0.4.8)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchdiffeq in /usr/local/lib/python3.9/dist-packages (0.2.3)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from torchdiffeq) (1.10.1)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from torchdiffeq) (2.0.0+cu118)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.9/dist-packages (from scipy>=1.4.0->torchdiffeq) (1.24.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.3.0->torchdiffeq) (3.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.3.0->torchdiffeq) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.3.0->torchdiffeq) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.3.0->torchdiffeq) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.3.0->torchdiffeq) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.3.0->torchdiffeq) (1.11.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.3.0->torchdiffeq) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.3.0->torchdiffeq) (16.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.3.0->torchdiffeq) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.3.0->torchdiffeq) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fastdtw in /usr/local/lib/python3.9/dist-packages (0.3.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fastdtw) (1.24.3)

# %%
# !git clone https://github.com/gabriellarson/PEMSfiles
# %cd PEMSfiles

# %%
from collections import OrderedDict
from typing import List, Tuple

import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn

import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split, Subset, Dataset


import flwr as fl
from flwr.common import Metrics
import ray

DEVICE = torch.device("cpu")  # Try "cuda" to train on GPU
print(
    f"Training on {DEVICE} using PyTorch {torch.__version__} and Flower {fl.__version__}"
)
# Out:
# Training on cpu using PyTorch 2.0.0+cu118 and Flower 1.5.0.dev20230421

# %% [markdown]
# ## Loads the data in a time series fashion
# - Asks for 3 things:
#    - Time format: hours, days or weeks
#    - Number of past observations required to predict
#    - How many predictions are to be made (e.g 3 if we want to predict the flow for next 3 hours (depends on time format))
#
# \
#
# - Function defination
#    - data_len: number of points needed for test train
#    - points_per_hour: is $12$ because we have observation of every 5 minutes making total of of $12$ observations in an hour
#    - save: want to save the data extracted from this particular function call
#
#
# ```py
#    def read_and_generate_dataset(graph_signal_matrix_filename,
#                                                      num_of_weeks, num_of_days,
#                                                      num_of_hours, num_for_predict,data_len,
#                                                      points_per_hour=12, save=False):
# ```
#
# ```py
#    all_data = read_and_generate_dataset(graph_signal_matrix_filename, 0, 0, num_of_hours, num_for_predict, data_len, points_per_hour=points_per_hour, save=True)
# ```
#
# - By default $60\%$ train and $20\%$ validation, test
#
# - See configuration fill if we want to use different dataset i.e. PEMS07 etc
#
# - is normalized

# %% [markdown]
# # Code to extract/format PEMS data
#
# see: https://github.com/guoshnBJTU/ASTGCN-r-pytorch

# %%
import os
import numpy as np
import argparse
import configparser


def search_data(sequence_length, num_of_depend, label_start_idx,
                num_for_predict, units, points_per_hour):
    '''
    Parameters
    ----------
    sequence_length: int, length of all history data
    num_of_depend: can be hours, days, and weeks; int,
    label_start_idx: int, the first index of predicting target
    num_for_predict: int, the number of points will be predicted for each sample
    units: int, week: 7 * 24, day: 24, recent(hour): 1
    points_per_hour: int, number of points per hour, depends on data
    Returns
    ----------
    list of indices for eg in 24 hour case it would be list([0, 11], [12, 23]), it has len of prev pred required for next. len of each item in list is the number of total prediction we want to make, just like time series format

    list[(start_idx, end_idx)]
    '''

    if points_per_hour < 0:
        raise ValueError("points_per_hour should be greater than 0!")

    #check if we have more rows than the number of units we are predicting for, for 12 hours it should be greater than 12
    if label_start_idx + num_for_predict > sequence_length:
        return None

    x_idx = []
    #based on the unit of prediction get the slices of data in a time series format
    for i in range(1, num_of_depend + 1):
        start_idx = label_start_idx - points_per_hour * units * i
        end_idx = start_idx + num_for_predict
        if start_idx >= 0:
            x_idx.append((start_idx, end_idx))
        else:
            return None

    if len(x_idx) != num_of_depend:
        return None

    return x_idx[::-1]


def get_sample_indices(data_sequence, num_of_weeks, num_of_days, num_of_hours,
                       label_start_idx, num_for_predict, points_per_hour=12):
    '''
    Parameters
    ----------
    data_sequence: np.ndarray
                   shape is (sequence_length, num_of_vertices, num_of_features)
    num_of_weeks, num_of_days, num_of_hours: int
    label_start_idx: int, the first index of predicting target, 预测值开始的那个点
    num_for_predict: int,
                     the number of points will be predicted for each sample
    points_per_hour: int, default 12, number of points per hour
    Returns
    ----------
    week_sample: np.ndarray
                 shape is (num_of_weeks * points_per_hour,
                           num_of_vertices, num_of_features)
    day_sample: np.ndarray
                 shape is (num_of_days * points_per_hour,
                           num_of_vertices, num_of_features)
    hour_sample: np.ndarray
                 shape is (num_of_hours * points_per_hour,
                           num_of_vertices, num_of_features)
    target: np.ndarray
            shape is (num_for_predict, num_of_vertices, num_of_features)
    '''
    week_sample, day_sample, hour_sample = None, None, None

    '''check if the current index is greater than the number of prediction we are doing e.g. if we are predicting for
        for next 12 hours then the '''

    if label_start_idx + num_for_predict > data_sequence.shape[0]:
        return week_sample, day_sample, hour_sample, None

    #following check if we are doing predictions on hours, days or weeks
    if num_of_weeks > 0:
        week_indices = search_data(data_sequence.shape[0], num_of_weeks,
                                   label_start_idx, num_for_predict,
                                   7 * 24, points_per_hour)
        if not week_indices:
            return None, None, None, None

        week_sample = np.concatenate([data_sequence[i: j]
                                      for i, j in week_indices], axis=0)

    if num_of_days > 0:
        day_indices = search_data(data_sequence.shape[0], num_of_days,
                                  label_start_idx, num_for_predict,
                                  24, points_per_hour)
        if not day_indices:
            return None, None, None, None

        day_sample = np.concatenate([data_sequence[i: j]
                                     for i, j in day_indices], axis=0)
    # lets say we are doing predictions for next 12 hours based on data of previous 12 hours
    if num_of_hours > 0:
        # the following function will find the indices based on the given parameters
        hour_indices = search_data(data_sequence.shape[0], num_of_hours,
                                   label_start_idx, num_for_predict,
                                   1, points_per_hour)
        if not hour_indices:
            return None, None, None, None
        
        # linear sequence of hours required for the next prediction
        hour_sample = np.concatenate([data_sequence[i: j]
                                      for i, j in hour_indices], axis=0)

    target = data_sequence[label_start_idx: label_start_idx + num_for_predict]

    return week_sample, day_sample, hour_sample, target


def read_and_generate_dataset(graph_signal_matrix_filename,
                                                     num_of_weeks, num_of_days,
                                                     num_of_hours, num_for_predict,data_len,
                                                     points_per_hour=12, save=False):
    '''
    Parameters
    ----------
    graph_signal_matrix_filename: str, path of graph signal matrix file
    num_of_weeks, num_of_days, num_of_hours: int
    num_for_predict: int
    points_per_hour: int, default 12, depends on data

    Returns
    ----------
    feature: np.ndarray,
             shape is (num_of_samples, num_of_depend * points_per_hour,
                       num_of_vertices, num_of_features)
    target: np.ndarray,
            shape is (num_of_samples, num_of_vertices, num_for_predict)
    '''
    data_seq = np.load(graph_signal_matrix_filename)['data']  # (sequence_length, num_of_vertices, num_of_features)
    data_seq = data_seq[0:data_len]

    all_samples = []
    for idx in range(data_seq.shape[0]): #iterate over entire data
        '''then  for each row call the following function
        this functions returns the indices of the data required for prediction, 
        if we have num_hours = 12 then its output would be '''
        sample = get_sample_indices(data_seq, num_of_weeks, num_of_days, 
                                    num_of_hours, idx, num_for_predict,
                                    points_per_hour)
        if ((sample[0] is None) and (sample[1] is None) and (sample[2] is None)):
            continue

        week_sample, day_sample, hour_sample, target = sample
        sample = []  # [(week_sample),(day_sample),(hour_sample),target,time_sample]

        if num_of_weeks > 0:
            week_sample = np.expand_dims(week_sample, axis=0).transpose((0, 2, 3, 1))  # (1,N,F,T)
            sample.append(week_sample)

        if num_of_days > 0:
            day_sample = np.expand_dims(day_sample, axis=0).transpose((0, 2, 3, 1))  # (1,N,F,T)
            sample.append(day_sample)

        if num_of_hours > 0:
            hour_sample = np.expand_dims(hour_sample, axis=0).transpose((0, 2, 3, 1))  # (1,N,F,T)
            sample.append(hour_sample)

        #get only the target value from the next to be predicted row
        target = np.expand_dims(target, axis=0).transpose((0, 2, 3, 1))[:, :, 0, :]  # (1,N,T)
        sample.append(target)

        time_sample = np.expand_dims(np.array([idx]), axis=0)  # (1,1)
        sample.append(time_sample)

        all_samples.append(
            sample)  # sampe：[(week_sample),(day_sample),(hour_sample),target,time_sample] = [(1,N,F,Tw),(1,N,F,Td),(1,N,F,Th),(1,N,Tpre),(1,1)]

    split_line1 = int(len(all_samples) * 0.6)
    split_line2 = int(len(all_samples) * 0.8)

    training_set = [np.concatenate(i, axis=0)
                    for i in zip(*all_samples[:split_line1])]  # [(B,N,F,Tw),(B,N,F,Td),(B,N,F,Th),(B,N,Tpre),(B,1)]
    validation_set = [np.concatenate(i, axis=0)
                      for i in zip(*all_samples[split_line1: split_line2])]
    testing_set = [np.concatenate(i, axis=0)
                   for i in zip(*all_samples[split_line2:])]

    train_x = np.concatenate(training_set[:-2], axis=-1)  # (B,N,F,T')
    val_x = np.concatenate(validation_set[:-2], axis=-1)
    test_x = np.concatenate(testing_set[:-2], axis=-1)

    train_target = training_set[-2]  # (B,N,T)
    val_target = validation_set[-2]
    test_target = testing_set[-2]

    train_timestamp = training_set[-1]  # (B,1)
    val_timestamp = validation_set[-1]
    test_timestamp = testing_set[-1]

    (stats, train_x_norm, val_x_norm, test_x_norm) = normalization(train_x, val_x, test_x)

    all_data = {
        'train': {
            'x': train_x_norm,
            'target': train_target,
            'timestamp': train_timestamp,
        },
        'val': {
            'x': val_x_norm,
            'target': val_target,
            'timestamp': val_timestamp,
        },
        'test': {
            'x': test_x_norm,
            'target': test_target,
            'timestamp': test_timestamp,
        },
        'stats': {
            '_mean': stats['_mean'],
            '_std': stats['_std'],
        }
    }
    print('train x:', all_data['train']['x'].shape)
    print('train target:', all_data['train']['target'].shape)
    print('train timestamp:', all_data['train']['timestamp'].shape)
    print()
    print('val x:', all_data['val']['x'].shape)
    print('val target:', all_data['val']['target'].shape)
    print('val timestamp:', all_data['val']['timestamp'].shape)
    print()
    print('test x:', all_data['test']['x'].shape)
    print('test target:', all_data['test']['target'].shape)
    print('test timestamp:', all_data['test']['timestamp'].shape)
    print()
    print('train data _mean :', stats['_mean'].shape, stats['_mean'])
    print('train data _std :', stats['_std'].shape, stats['_std'])

    if save:
        file = os.path.basename(graph_signal_matrix_filename).split('.')[0]
        dirpath = os.path.dirname(graph_signal_matrix_filename)
        filename = os.path.join(dirpath, file + '_r' + str(num_of_hours) + '_d' + str(num_of_days) + '_w' + str(num_of_weeks)) + '_astcgn'
        print('save file:', filename)
        np.savez_compressed(filename,
                            train_x=all_data['train']['x'], train_target=all_data['train']['target'],
                            train_timestamp=all_data['train']['timestamp'],
                            val_x=all_data['val']['x'], val_target=all_data['val']['target'],
                            val_timestamp=all_data['val']['timestamp'],
                            test_x=all_data['test']['x'], test_target=all_data['test']['target'],
                            test_timestamp=all_data['test']['timestamp'],
                            mean=all_data['stats']['_mean'], std=all_data['stats']['_std']
                            )
    return all_data


def normalization(train, val, test):
    '''
    Parameters
    ----------
    train, val, test: np.ndarray (B,N,F,T)
    Returns
    ----------
    stats: dict, two keys: mean and std
    train_norm, val_norm, test_norm: np.ndarray,
                                     shape is the same as original
    '''

    assert train.shape[1:] == val.shape[1:] and val.shape[1:] == test.shape[1:]  # ensure the num of nodes is the same
    mean = train.mean(axis=(0,1,3), keepdims=True)
    std = train.std(axis=(0,1,3), keepdims=True)
    print('mean.shape:',mean.shape)
    print('std.shape:',std.shape)

    def normalize(x):
        return (x - mean) / std

    train_norm = normalize(train)
    val_norm = normalize(val)
    test_norm = normalize(test)

    return {'_mean': mean, '_std': std}, train_norm, val_norm, test_norm


# prepare dataset
parser = argparse.ArgumentParser()
parser.add_argument("--config", default='PEMS04.conf', type=str,
                    help="configuration file path")
args, unknown = parser.parse_known_args()
config = configparser.ConfigParser()
print('Read configuration file: %s' % (args.config))
config.read(args.config)
data_config = config['Data']
training_config = config['Training']

adj_filename = data_config['adj_filename']
graph_signal_matrix_filename = data_config['graph_signal_matrix_filename']
if config.has_option('Data', 'id_filename'):
    id_filename = data_config['id_filename']
else:
    id_filename = None

num_of_vertices = int(data_config['num_of_vertices']) #of graphs
points_per_hour = int(data_config['points_per_hour']) #each entry is of 5 min so points per hour will be 12
num_for_predict = int(data_config['num_for_predict']) #next prediction, for now we are doing for next 12 hours
len_input = int(data_config['len_input'])
dataset_name = data_config['dataset_name']
num_of_weeks = int(training_config['num_of_weeks']) #all values to be set in config file, num_* variables denote the length of past readings we need to predict the next hour's traffic
num_of_days = int(training_config['num_of_days'])
num_of_hours = int(training_config['num_of_hours'])
num_of_vertices = int(data_config['num_of_vertices'])
points_per_hour = int(data_config['points_per_hour'])
num_for_predict = int(data_config['num_for_predict'])
graph_signal_matrix_filename = data_config['graph_signal_matrix_filename'] #dataset name

data = np.load(graph_signal_matrix_filename)['data']
#print("keys:", data.files)

data_len = 10000
all_data = read_and_generate_dataset(graph_signal_matrix_filename, 0, 0, num_of_hours, num_for_predict, data_len, points_per_hour=points_per_hour, save=True)
# Out:
# Read configuration file: PEMS04.conf
# (raylet) [2023-04-25 03:32:00,676 E 4261 4261] (raylet) node_manager.cc:3040: 2 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 1b06693a83abbcdf033f50fdd0612c9c6d616fcfec3a3bad320b37df, IP: 172.28.0.12) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.28.0.12`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# mean.shape: (1, 1, 3, 1)
# std.shape: (1, 1, 3, 1)
# train x: (5986, 307, 3, 12)
# train target: (5986, 307, 12)
# train timestamp: (5986, 1)
#
# val x: (1995, 307, 3, 12)
# val target: (1995, 307, 12)
# val timestamp: (1995, 1)
#
# test x: (1996, 307, 3, 12)
# test target: (1996, 307, 12)
# test timestamp: (1996, 1)
#
# train data _mean : (1, 1, 3, 1) [[[[2.05570672e+02]
#    [5.01795602e-02]
#    [6.34796641e+01]]]]
# train data _std : (1, 1, 3, 1) [[[[1.54753677e+02]
#    [4.54976570e-02]
#    [7.74333291e+00]]]]
# save file: PEMS04_r1_d0_w0_astcgn

# %% [markdown]
# ## loading saved data

# %%
file_data = all_data

train_x = file_data['train']['x']  # (10181, 307, 3, 12)
train_x = train_x[:, :, 0:1, :]
train_y= file_data['train']['timestamp'].reshape(-1)
train_target = file_data['train']['target']  # (10181, 307, 12)

val_x = file_data['val']['x']
val_x = val_x[:, :, 0:1, :]
val_target = file_data['val']['target']
val_y= file_data['val']['timestamp'].reshape(-1)

test_x = file_data['test']['x']
test_x = test_x[:, :, 0:1, :]
test_y= file_data['test']['timestamp'].reshape(-1)
test_target = file_data['test']['target']

mean = file_data['stats']['_mean'][:, :, 0:1, :]  # (1, 1, 3, 1)
std = file_data['stats']['_std'][:, :, 0:1, :]  # (1, 1, 3, 1)

# %%
train_x = np.vstack((train_x, val_x))
train_y = np.concatenate((train_y, val_y))

# %% [markdown]
# ## LSTM model

# %%
class GRU(nn.Module):
    def __init__(self, input_size, hidden_units):
        super().__init__()
        self.input_size = input_size  # this is the number of features
        self.hidden_units = hidden_units
        self.num_layers = 1

        self.gru = nn.GRU(
            input_size=input_size,
            hidden_size=hidden_units,
            batch_first=True,
            num_layers=self.num_layers
        )

        self.linear = nn.Linear(in_features=self.hidden_units, out_features=1)

    def forward(self, x):
        batch_size = x.shape[0]
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_units).requires_grad_()

        _, hn = self.gru(x, h0)
        out = self.linear(hn[0]).flatten()  # First dim of Hn is num_layers, which is set to 1 above.

        return out

# %%
data_batch_size_lstm = 16

NUM_CLIENTS = 10
epoch = 20
NUM_ROUNDS = 10

# %% [markdown]
# ## get model parameters to aggregate

# %%
def get_parameters(net) -> List[np.ndarray]:
    weights =  [val.cpu().numpy() for _, val in net.state_dict().items()]
    print([(val.cpu().numpy().shape, key)  for key, val in net.state_dict().items()])
    return weights

# %% [markdown]
# ## Flower

# %%
def masked_mape_np(y_true, y_pred, null_val=np.nan):
    with np.errstate(divide='ignore', invalid='ignore'):
        mape = np.abs((y_pred - y_true) / y_true)
        mape = np.nan_to_num(mape)
        return np.mean(mape) * 100


def masked_mae_np(y_true, y_pred, null_val=np.nan):
    mae = np.abs(y_true - y_pred)
    return np.mean(np.nan_to_num(mae))

# %%
def train(model, data_loader, optimizer, epochs, loss_function):

    num_batches = len(data_loader)
    total_loss = 0
    epoch_loss = []
    model.train()
    for ix_epoch in range(epochs):
        total_loss = 0
        for X, y in data_loader:
            output = model(X)
            #print('output shape', output.shape)
            loss = torch.sqrt(loss_function(output, y))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
        epoch_loss.append(total_loss)
        print(f"Epoch {ix_epoch+1}: train loss {total_loss}")

    return sum(epoch_loss) / epochs
    

def test(model, data_loader, loss_function):
    
    batch_rmse_loss = 0
    batch_mae_loss = 0
    batch_mape_loss = 0

    model.eval()
    pred_output = []
    with torch.no_grad():
        for idx , (X, y) in enumerate(data_loader):
            output = model(X)
            loss = torch.sqrt(torch.mean((output-y)**2))
            batch_rmse_loss += loss.item()
            batch_mae_loss += masked_mae_np(output, y)
            batch_mape_loss += masked_mae_np(output, y)

    print(f'Eval RMSE: {batch_rmse_loss/idx}: {idx}')
    return batch_rmse_loss / (idx + 1), batch_mae_loss / (idx + 1), batch_mape_loss / (idx + 1)

# %%
## very new PEMS DATA SHAPE
class PEMSDataset(Dataset):
    def __init__(self, data_x, labels):
        self.shape = (train_x.shape[-1], train_x.shape[1])
        self.data =  np.array([np.reshape(x, self.shape) for x in data_x])
        self.labels = labels

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):
        data_arr = self.data[idx].copy()
        return torch.from_numpy(data_arr).float(), torch.from_numpy(np.array(self.labels[idx])).float()

# %%
def load_datasets(NUM_CLIENTS, BATCH_SIZE, train_x, train_y, test_x, test_y):

    dataset = PEMSDataset(train_x, train_y)
    dataset_t = PEMSDataset(test_x, test_y)

    feature_size = dataset.data.shape[1]
    print('feature size', feature_size)



    inds = np.array_split(np.random.randint(len(dataset), size=len(dataset)), NUM_CLIENTS)
    trainloaders = []
    valloaders = []
    for idx in inds:
        trainloaders.append(DataLoader(Subset(dataset, idx), batch_size=BATCH_SIZE, shuffle=True))


    inds = np.array_split(np.random.randint(len(dataset_t), size=len(dataset_t)), NUM_CLIENTS)
    for idx in inds:
        valloaders.append(DataLoader(Subset(dataset_t, idx), batch_size=BATCH_SIZE, shuffle=True))
        
    testloader = DataLoader(dataset_t, batch_size=BATCH_SIZE)
    return trainloaders, valloaders, testloader


trainloaders, valloaders, testloader = load_datasets(NUM_CLIENTS, data_batch_size_lstm , train_x, train_y, test_x, test_y)
# Out:
# feature size 12

# %%
dataset = PEMSDataset(train_x, train_y)
dataset_t = PEMSDataset(test_x, test_y)

feature_size = dataset.data.shape[2]
print('feature size', feature_size)


print('train shape', train_x.shape)
print('test shape', test_x.shape)
print("Total train size:", len(train_y))
print("Total test size:", len(test_y))
# Out:
# feature size 307
# train shape (7981, 307, 1, 12)
# test shape (1996, 307, 1, 12)
# Total train size: 7981
# Total test size: 1996

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, net, trainloader, valloader, optimiser, learning_rate, epochs, loss_function, ):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader
        self.loss_function = loss_function
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.optimiser = optimiser(net.parameters(), lr=self.learning_rate)

    def get_parameters(self, config):
        return get_parameters(self.net)

    def fit(self, parameters, config):
        set_parameters(self.net, parameters)
        loss = train(self.net, self.trainloader, self.optimiser , self.epochs, self.loss_function)
        return get_parameters(self.net), len(self.trainloader)*self.trainloader.batch_size, {"train_loss":loss}

    def evaluate(self, parameters, config):
        set_parameters(self.net, parameters)
        valid_rmse, valid_mae, valid_mape = test(self.net, self.valloader, self.loss_function)
        return valid_rmse, len(self.valloader)*self.valloader.batch_size , {'valid_mape':valid_mape, 'valid_mae':valid_mae, 'valid_rmse':valid_rmse}

# %%
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]

def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)

# %%
dataset.data.shape
# Out:
# (7981, 12, 307)

# %%
def client_fn(cid: str) -> FlowerClient:
    """Create a Flower client representing a single organization."""

    # Load model
    learning_rate = 1e-2
    num_hidden_units = 16
    #lr = args.lr
    loss_function = nn.SmoothL1Loss()
    input_size = dataset.data.shape[2]
    net = GRU(input_size=input_size, hidden_units=num_hidden_units).to(DEVICE)

    # will train and evaluate on their own unique data
    trainloader = trainloaders[int(cid)]
    valloader = valloaders[int(cid)]

    # Create a  single Flower client representing a single organization
    return FlowerClient(net=net, trainloader=trainloader, valloader=valloader, optimiser=torch.optim.AdamW , learning_rate=learning_rate, 
                        epochs=epoch , loss_function= loss_function )

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    # Multiply accuracy of each client by number of examples used

    valid_rmse = [num_examples * m["valid_rmse"] for num_examples, m in metrics]
    valid_mae = [num_examples * m["valid_mae"] for num_examples, m in metrics]
    valid_mape = [num_examples * m["valid_mape"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    valid_rmse_client = [m["valid_rmse"] for num_examples, m in metrics]
    valid_mae_client = [m["valid_mae"] for num_examples, m in metrics]
    valid_mape_client = [m["valid_mape"] for num_examples, m in metrics]


    # Aggregate and return custom metric (weighted average)
    return {'average_metrics':{'valid_mape':sum(valid_mape)/sum(examples), 'valid_mae':sum(valid_mae)/sum(examples), 'valid_rmse':sum(valid_rmse)/sum(examples)},
            'client_metrics': {'valid_mape':valid_mape_client, 'valid_mae':valid_mae_client, 'valid_rmse':valid_rmse_client, 'examples': examples}}

def fit_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    loss = [num_examples * m["train_loss"] for num_examples, m in metrics]
    loss_client = [m["train_loss"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]
    return {'client_metrics': {"loss":loss_client}, 'examples':examples,'average_metrics':{'average loss': sum(loss)/sum(examples)}}



params = get_parameters(GRU(input_size=train_x.shape[1], hidden_units=64))

# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,  # Sample 100% of available clients for training
    fraction_evaluate=0.5,  # Sample 50% of available clients for evaluation
    min_fit_clients=NUM_CLIENTS,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=NUM_CLIENTS,  # Wait until all 10 clients are available
    evaluate_metrics_aggregation_fn =  weighted_average,
    fit_metrics_aggregation_fn = fit_average
)

# Specify client resources if you need GPU (defaults to 1 CPU and 0 GPU)
client_resources = None
if DEVICE.type == "cuda":
    client_resources = {"num_gpus": 1}


# Start simulation
flower_history = fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
    strategy=strategy,
    client_resources=client_resources,
        ray_init_args = {
            "include_dashboard": False, # we need this one for tracking
            "num_cpus": 8,
  }
)
# Out:
# INFO flwr 2023-04-25 03:32:52,581 | app.py:146 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# 2023-04-25 03:33:03,549	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 2307502080 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=4.10gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2023-04-25 03:33:04,932	INFO worker.py:1553 -- Started a local Ray instance.
# INFO flwr 2023-04-25 03:33:07,509 | app.py:180 | Flower VCE: Ray initialized with resources: {'CPU': 8.0, 'object_store_memory': 3998118297.0, 'node:172.28.0.12': 1.0, 'memory': 7996236596.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'CPU': 8.0, 'object_store_memory': 3998118297.0, 'node:172.28.0.12': 1.0, 'memory': 7996236596.0}
# INFO flwr 2023-04-25 03:33:07,517 | server.py:86 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2023-04-25 03:33:07,526 | server.py:273 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# (pid=9285) 2023-04-25 03:33:29.886666: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO flwr 2023-04-25 03:33:39,934 | server.py:277 | Received initial parameters from one random client
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2023-04-25 03:33:39,941 | server.py:88 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2023-04-25 03:33:39,944 | server.py:101 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2023-04-25 03:33:39,947 | server.py:218 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 10)
# (launch_and_fit pid=9285) Epoch 1: train loss 3164.37313079834
# (launch_and_fit pid=9285) Epoch 2: train loss 3159.4226570129395
# (launch_and_fit pid=9285) Epoch 3: train loss 3159.5572509765625
# (launch_and_fit pid=9285) Epoch 4: train loss 3156.4213943481445
# (launch_and_fit pid=9285) Epoch 5: train loss 3152.9506797790527
# (launch_and_fit pid=9285) Epoch 6: train loss 3144.945732116699
# (launch_and_fit pid=9285) Epoch 7: train loss 3146.4718894958496
# (launch_and_fit pid=9285) Epoch 8: train loss 3140.7210540771484
# (launch_and_fit pid=9285) Epoch 9: train loss 3140.273639678955
# (launch_and_fit pid=9285) Epoch 10: train loss 3133.747570037842
# (launch_and_fit pid=9285) Epoch 11: train loss 3128.108139038086
# (launch_and_fit pid=9285) Epoch 12: train loss 3130.6903114318848
# (launch_and_fit pid=9285) Epoch 13: train loss 3127.103530883789
# (launch_and_fit pid=9285) Epoch 14: train loss 3120.250778198242
# (launch_and_fit pid=9285) Epoch 15: train loss 3120.713954925537
# (launch_and_fit pid=9285) Epoch 16: train loss 3115.8156967163086
# (launch_and_fit pid=9285) Epoch 17: train loss 3115.5559005737305
# (launch_and_fit pid=9285) Epoch 18: train loss 3108.635772705078
# (launch_and_fit pid=9285) Epoch 19: train loss 3108.0972595214844
# (launch_and_fit pid=9285) Epoch 20: train loss 3103.9287338256836
# (pid=9284) 2023-04-25 03:34:25.669474: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (pid=9746) 2023-04-25 03:34:25.675485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (raylet) Spilled 2916 MiB, 4 objects, write throughput 103 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# (launch_and_fit pid=9285) Epoch 1: train loss 3163.5915718078613
# (launch_and_fit pid=9285) Epoch 2: train loss 3156.8408851623535
# (launch_and_fit pid=9285) Epoch 3: train loss 3148.7526931762695
# (launch_and_fit pid=9285) Epoch 4: train loss 3152.7265396118164
# (launch_and_fit pid=9285)
# (launch_and_fit pid=9285) Epoch 5: train loss 3147.0061264038086
# (launch_and_fit pid=9285) Epoch 6: train loss 3144.810691833496
# (launch_and_fit pid=9285) Epoch 7: train loss 3137.6574630737305
# (launch_and_fit pid=9285) Epoch 8: train loss 3137.191509246826
# (launch_and_fit pid=9285) Epoch 9: train loss 3133.0722846984863
# (launch_and_fit pid=9285) Epoch 10: train loss 3129.8191146850586
# (launch_and_fit pid=9285) Epoch 11: train loss 3127.234519958496
# (launch_and_fit pid=9285) Epoch 12: train loss 3124.9541206359863
# (launch_and_fit pid=9285) Epoch 13: train loss 3121.4855041503906
# (launch_and_fit pid=9285) Epoch 14: train loss 3119.232048034668
# (launch_and_fit pid=9285) Epoch 15: train loss 3116.169033050537
# (launch_and_fit pid=9285) Epoch 16: train loss 3111.7986907958984
# (launch_and_fit pid=9285) Epoch 17: train loss 3113.2284545898438
# (launch_and_fit pid=9285) Epoch 18: train loss 3106.4541091918945
# (launch_and_fit pid=9285) Epoch 19: train loss 3102.3509254455566
# (launch_and_fit pid=9285) Epoch 20: train loss 3096.2384185791016
# (launch_and_fit pid=9285) Epoch 1: train loss 3154.0015563964844
# (launch_and_fit pid=9285) Epoch 2: train loss 3150.011745452881
# (launch_and_fit pid=9285) Epoch 3: train loss 3148.255626678467
# (launch_and_fit pid=9285) Epoch 4: train loss 3144.9661445617676
# (launch_and_fit pid=9285) Epoch 5: train loss 3140.386447906494
# (launch_and_fit pid=9285) Epoch 6: train loss 3139.387191772461
# (launch_and_fit pid=9285) Epoch 7: train loss 3133.627368927002
# (launch_and_fit pid=9285) Epoch 8: train loss 3129.6160621643066
# (launch_and_fit pid=9285) Epoch 9: train loss 3129.9653129577637
# (launch_and_fit pid=9285) Epoch 10: train loss 3124.7160453796387
# (launch_and_fit pid=9285) Epoch 11: train loss 3121.3907203674316
# (launch_and_fit pid=9285) Epoch 12: train loss 3114.9195594787598
# (launch_and_fit pid=9285) Epoch 13: train loss 3115.57515335083
# (launch_and_fit pid=9285) Epoch 14: train loss 3113.2878074645996
# (launch_and_fit pid=9285) Epoch 15: train loss 3106.3866844177246
# (launch_and_fit pid=9285) Epoch 16: train loss 3107.207374572754
# (launch_and_fit pid=9285) Epoch 17: train loss 3103.935894012451
# (launch_and_fit pid=9285) Epoch 18: train loss 3101.579879760742
# (launch_and_fit pid=9285) Epoch 19: train loss 3094.4847145080566
# (launch_and_fit pid=9285) Epoch 20: train loss 3087.670585632324
# (launch_and_fit pid=9285) Epoch 1: train loss 3197.513080596924
# (launch_and_fit pid=9285) Epoch 2: train loss 3190.169387817383
# (launch_and_fit pid=9285) Epoch 3: train loss 3186.8514823913574
# (launch_and_fit pid=9285) Epoch 4: train loss 3186.503406524658
# (launch_and_fit pid=9285) Epoch 5: train loss 3183.4188537597656
# (launch_and_fit pid=9285) Epoch 6: train loss 3181.418312072754
# (launch_and_fit pid=9285) Epoch 7: train loss 3174.2451934814453
# (launch_and_fit pid=9285) Epoch 8: train loss 3174.838695526123
# (launch_and_fit pid=9285) Epoch 9: train loss 3168.951919555664
# (launch_and_fit pid=9285) Epoch 10: train loss 3166.9676933288574
# (launch_and_fit pid=9285) Epoch 11: train loss 3166.4727172851562
# (launch_and_fit pid=9285) Epoch 12: train loss 3162.185089111328
# (launch_and_fit pid=9285) Epoch 13: train loss 3157.5143394470215
# (launch_and_fit pid=9285) Epoch 14: train loss 3150.2781715393066
# (launch_and_fit pid=9285) Epoch 15: train loss 3147.1851768493652
# (launch_and_fit pid=9285) Epoch 16: train loss 3149.9611778259277
# (launch_and_fit pid=9285) Epoch 17: train loss 3144.345558166504
# (launch_and_fit pid=9285) Epoch 18: train loss 3141.909740447998
# (launch_and_fit pid=9285) Epoch 19: train loss 3138.2741622924805
# (launch_and_fit pid=9285) Epoch 20: train loss 3136.8673820495605
# (launch_and_fit pid=9285) Epoch 1: train loss 3166.7010765075684
# (launch_and_fit pid=9285) Epoch 2: train loss 3162.455379486084
# (launch_and_fit pid=9285) Epoch 3: train loss 3158.7496757507324
# (launch_and_fit pid=9285) Epoch 4: train loss 3157.1552200317383
# (launch_and_fit pid=9285) Epoch 5: train loss 3153.4254302978516
# (launch_and_fit pid=9285) Epoch 6: train loss 3150.4381523132324
# (launch_and_fit pid=9285) Epoch 7: train loss 3145.5503578186035
# (launch_and_fit pid=9285) Epoch 8: train loss 3138.497589111328
# (launch_and_fit pid=9284) Epoch 1: train loss 3080.329330444336
# (launch_and_fit pid=9746) Epoch 1: train loss 3172.1790809631348
# (launch_and_fit pid=9285) Epoch 9: train loss 3139.430191040039
# (launch_and_fit pid=9746) Epoch 2: train loss 3169.1485900878906
# (launch_and_fit pid=9284) Epoch 2: train loss 3076.4792404174805
# (launch_and_fit pid=9285) Epoch 10: train loss 3135.765064239502
# (launch_and_fit pid=9746) Epoch 3: train loss 3165.4618072509766
# (launch_and_fit pid=9284) Epoch 3: train loss 3075.955554962158
# (launch_and_fit pid=9285) Epoch 11: train loss 3131.364761352539
# (launch_and_fit pid=9284) Epoch 4: train loss 3072.297019958496
# (launch_and_fit pid=9746) Epoch 4: train loss 3162.496078491211
# (launch_and_fit pid=9284) Epoch 5: train loss 3064.9588775634766
# (launch_and_fit pid=9285) Epoch 12: train loss 3128.367214202881
# (launch_and_fit pid=9285) Epoch 13: train loss 3125.8360290527344
# (launch_and_fit pid=9746) Epoch 5: train loss 3158.8070793151855
# (launch_and_fit pid=9284) Epoch 6: train loss 3061.562568664551
# (raylet) Spilled 5104 MiB, 7 objects, write throughput 90 MiB/s.
# (launch_and_fit pid=9746) Epoch 6: train loss 3157.2929306030273
# (launch_and_fit pid=9285) Epoch 14: train loss 3124.2944374084473
# (launch_and_fit pid=9285) Epoch 15: train loss 3123.6218795776367
# (launch_and_fit pid=9746) Epoch 7: train loss 3150.11527633667
# (launch_and_fit pid=9284) Epoch 7: train loss 3059.2513427734375
# (launch_and_fit pid=9285) Epoch 16: train loss 3114.185012817383
# (launch_and_fit pid=9746) Epoch 8: train loss 3150.329174041748
# (launch_and_fit pid=9284) Epoch 8: train loss 3055.004207611084
# (launch_and_fit pid=9746) Epoch 9: train loss 3147.2219886779785
# (launch_and_fit pid=9285) Epoch 17: train loss 3116.9259719848633
# (launch_and_fit pid=9284) Epoch 9: train loss 3054.827350616455
# (launch_and_fit pid=9285) Epoch 18: train loss 3111.495059967041
# (launch_and_fit pid=9746) Epoch 10: train loss 3144.549419403076
# (launch_and_fit pid=9285) Epoch 19: train loss 3105.6604385375977
# (launch_and_fit pid=9284) Epoch 10: train loss 3048.7206115722656
# (launch_and_fit pid=9746) Epoch 11: train loss 3137.538959503174
# (launch_and_fit pid=9285) Epoch 20: train loss 3106.3768920898438
# (launch_and_fit pid=9284) Epoch 11: train loss 3044.4596366882324
# (launch_and_fit pid=9284) Epoch 12: train loss 3043.5380897521973
# (launch_and_fit pid=9746) Epoch 12: train loss 3137.0624084472656
# (launch_and_fit pid=9285) Epoch 1: train loss 3115.0340843200684
# (launch_and_fit pid=9284) Epoch 13: train loss 3042.0173149108887
# (launch_and_fit pid=9746) Epoch 13: train loss 3132.387535095215
# (launch_and_fit pid=9746) Epoch 14: train loss 3130.4816856384277
# (launch_and_fit pid=9285) Epoch 2: train loss 3112.595359802246
# (launch_and_fit pid=9284) Epoch 14: train loss 3039.3373985290527
# (launch_and_fit pid=9284) Epoch 15: train loss 3035.0341873168945
# (launch_and_fit pid=9285) Epoch 3: train loss 3109.2207946777344
# (launch_and_fit pid=9746) Epoch 15: train loss 3122.4195556640625
# (launch_and_fit pid=9284) Epoch 16: train loss 3030.6850357055664
# (launch_and_fit pid=9746) Epoch 16: train loss 3123.9971199035645
# (launch_and_fit pid=9285) Epoch 4: train loss 3102.7681579589844
# (launch_and_fit pid=9746) Epoch 17: train loss 3122.828788757324
# (launch_and_fit pid=9284) Epoch 17: train loss 3027.6631355285645
# (launch_and_fit pid=9746) Epoch 18: train loss 3117.597770690918
# (launch_and_fit pid=9285) Epoch 5: train loss 3102.2403106689453
# (launch_and_fit pid=9284) Epoch 18: train loss 3022.116558074951
# (launch_and_fit pid=9746) Epoch 19: train loss 3112.565330505371
# (launch_and_fit pid=9284) Epoch 19: train loss 3023.4943923950195
# (launch_and_fit pid=9285) Epoch 6: train loss 3097.785846710205
# (launch_and_fit pid=9746) Epoch 20: train loss 3107.2780685424805
# (launch_and_fit pid=9285) Epoch 7: train loss 3093.710308074951
# (launch_and_fit pid=9284) Epoch 20: train loss 3017.9444541931152
# (launch_and_fit pid=9285) Epoch 8: train loss 3089.7661170959473
# (launch_and_fit pid=9746) Epoch 1: train loss 3140.3463821411133
# (launch_and_fit pid=9284) Epoch 1: train loss 3174.551555633545
# (launch_and_fit pid=9285) Epoch 9: train loss 3086.8727493286133
# (launch_and_fit pid=9746) Epoch 2: train loss 3133.421371459961
# (launch_and_fit pid=9284) Epoch 2: train loss 3172.288745880127
# (launch_and_fit pid=9285) Epoch 10: train loss 3084.5696716308594
# (launch_and_fit pid=9746) Epoch 3: train loss 3127.7587356567383
# (launch_and_fit pid=9284) Epoch 3: train loss 3166.893867492676
# (launch_and_fit pid=9285) Epoch 11: train loss 3081.1554527282715
# (launch_and_fit pid=9746) Epoch 4: train loss 3128.7481422424316
# (launch_and_fit pid=9285) Epoch 12: train loss 3081.3638076782227
# (launch_and_fit pid=9284) Epoch 4: train loss 3165.1897048950195
# (launch_and_fit pid=9746) Epoch 5: train loss 3122.3397636413574
# (launch_and_fit pid=9285) Epoch 13: train loss 3075.1171379089355
# (launch_and_fit pid=9284) Epoch 5: train loss 3160.265769958496
# (launch_and_fit pid=9285) Epoch 14: train loss 3072.685276031494
# (launch_and_fit pid=9746) Epoch 6: train loss 3121.472702026367
# (launch_and_fit pid=9285) Epoch 15: train loss 3066.0708961486816
# (launch_and_fit pid=9284) Epoch 6: train loss 3157.0945930480957
# (launch_and_fit pid=9746) Epoch 7: train loss 3117.739158630371
# (launch_and_fit pid=9284) Epoch 7: train loss 3156.0625915527344
# (launch_and_fit pid=9285) Epoch 16: train loss 3060.888042449951
# (launch_and_fit pid=9746) Epoch 8: train loss 3116.1561241149902
# (launch_and_fit pid=9285) Epoch 17: train loss 3057.689308166504
# (launch_and_fit pid=9284) Epoch 8: train loss 3147.739360809326
# (launch_and_fit pid=9746) Epoch 9: train loss 3109.8310737609863
# (launch_and_fit pid=9285) Epoch 18: train loss 3057.0338973999023
# (launch_and_fit pid=9284) Epoch 9: train loss 3144.703369140625
# (launch_and_fit pid=9746) Epoch 10: train loss 3105.9007110595703
# (launch_and_fit pid=9285) Epoch 19: train loss 3057.479679107666
# (launch_and_fit pid=9284) Epoch 10: train loss 3147.058246612549
# (launch_and_fit pid=9746) Epoch 11: train loss 3101.259174346924
# (launch_and_fit pid=9285) Epoch 20: train loss 3051.7694396972656
# (launch_and_fit pid=9746) Epoch 12: train loss 3100.483009338379
# (launch_and_fit pid=9284) Epoch 11: train loss 3141.7762145996094
# (launch_and_fit pid=9746) Epoch 13: train loss 3100.0399475097656
# (launch_and_fit pid=9284) Epoch 12: train loss 3138.6988945007324
# (launch_and_fit pid=9746) Epoch 14: train loss 3098.1190223693848
# (launch_and_fit pid=9284) Epoch 13: train loss 3133.6498947143555
# (launch_and_fit pid=9746) Epoch 15: train loss 3092.0737800598145
# (launch_and_fit pid=9284) Epoch 14: train loss 3134.49129486084
# (launch_and_fit pid=9746) Epoch 16: train loss 3089.2238807678223
# (launch_and_fit pid=9284) Epoch 15: train loss 3124.757537841797
# (launch_and_fit pid=9746) Epoch 17: train loss 3083.6212196350098
# (launch_and_fit pid=9284) Epoch 16: train loss 3125.0238609313965
# (launch_and_fit pid=9746) Epoch 18: train loss 3079.5294342041016
# (launch_and_fit pid=9284) Epoch 17: train loss 3123.823112487793
# (launch_and_fit pid=9746) Epoch 19: train loss 3078.12264251709
# (launch_and_fit pid=9284) Epoch 18: train loss 3121.4951400756836
# (launch_and_fit pid=9746) Epoch 20: train loss 3077.033531188965
# (launch_and_fit pid=9284) Epoch 19: train loss 3116.691230773926
# DEBUG flwr 2023-04-25 03:36:34,478 | server.py:232 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# DEBUG flwr 2023-04-25 03:36:34,543 | server.py:168 | evaluate_round 1: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 1: strategy sampled 5 clients (out of 10)
# (launch_and_fit pid=9284) Epoch 20: train loss 3115.102508544922
# (launch_and_evaluate pid=9284) Eval RMSE: 9600.706949869791: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9574.496500651041: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9585.443522135416: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9542.423258463541: 12
# DEBUG flwr 2023-04-25 03:37:52,555 | server.py:182 | evaluate_round 1 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 1 received 5 results and 0 failures
# DEBUG flwr 2023-04-25 03:37:52,558 | server.py:218 | fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 10)
# (launch_and_evaluate pid=9284) Eval RMSE: 9582.034098307291: 12
# (launch_and_fit pid=9284) Epoch 1: train loss 3104.8708534240723
# (launch_and_fit pid=9284) Epoch 2: train loss 3100.6781616210938
# (launch_and_fit pid=9284) Epoch 3: train loss 3096.5182762145996
# (launch_and_fit pid=9284) Epoch 4: train loss 3093.08455657959
# (launch_and_fit pid=9746) Epoch 1: train loss 3090.772964477539
# (launch_and_fit pid=9284) Epoch 5: train loss 3089.460548400879
# (launch_and_fit pid=9284) Epoch 6: train loss 3089.582202911377
# (launch_and_fit pid=9746) Epoch 2: train loss 3089.83145904541
# (launch_and_fit pid=9746) Epoch 3: train loss 3084.597438812256
# (launch_and_fit pid=9285) Epoch 1: train loss 3102.2479705810547
# (launch_and_fit pid=9284) Epoch 7: train loss 3085.6397819519043
# (launch_and_fit pid=9746) Epoch 4: train loss 3082.7321014404297
# (launch_and_fit pid=9285) Epoch 2: train loss 3099.400905609131
# (launch_and_fit pid=9746) Epoch 5: train loss 3081.5224266052246
# (launch_and_fit pid=9284) Epoch 8: train loss 3079.6267852783203
# (launch_and_fit pid=9285) Epoch 3: train loss 3099.2789268493652
# (launch_and_fit pid=9746) Epoch 6: train loss 3078.1329803466797
# (launch_and_fit pid=9284) Epoch 9: train loss 3079.1001358032227
# (launch_and_fit pid=9285) Epoch 4: train loss 3094.4463119506836
# (launch_and_fit pid=9746) Epoch 7: train loss 3070.1027870178223
# (launch_and_fit pid=9284) Epoch 10: train loss 3070.8474082946777
# (launch_and_fit pid=9746) Epoch 8: train loss 3068.7491569519043
# (launch_and_fit pid=9285) Epoch 5: train loss 3094.1462745666504
# (launch_and_fit pid=9285) Epoch 6: train loss 3088.3994674682617
# (launch_and_fit pid=9284) Epoch 11: train loss 3072.8787879943848
# (launch_and_fit pid=9746) Epoch 9: train loss 3067.1051292419434
# (launch_and_fit pid=9285) Epoch 7: train loss 3086.3258056640625
# (launch_and_fit pid=9284) Epoch 12: train loss 3070.198944091797
# (launch_and_fit pid=9746) Epoch 10: train loss 3065.2729873657227
# (launch_and_fit pid=9284) Epoch 13: train loss 3067.74666595459
# (launch_and_fit pid=9285) Epoch 8: train loss 3082.2738456726074
# (launch_and_fit pid=9746) Epoch 11: train loss 3060.793632507324
# (launch_and_fit pid=9284) Epoch 14: train loss 3066.48490524292
# (launch_and_fit pid=9746) Epoch 12: train loss 3060.598888397217
# (launch_and_fit pid=9285) Epoch 9: train loss 3079.651725769043
# (launch_and_fit pid=9284) Epoch 15: train loss 3064.2424507141113
# (launch_and_fit pid=9284) Epoch 16: train loss 3058.991912841797
# (launch_and_fit pid=9746) Epoch 13: train loss 3058.764190673828
# (launch_and_fit pid=9285) Epoch 10: train loss 3075.09676361084
# (launch_and_fit pid=9746) Epoch 14: train loss 3049.9133110046387
# (launch_and_fit pid=9285) Epoch 11: train loss 3072.0682945251465
# (launch_and_fit pid=9284) Epoch 17: train loss 3056.180965423584
# (launch_and_fit pid=9746) Epoch 15: train loss 3047.496654510498
# (launch_and_fit pid=9285) Epoch 12: train loss 3066.629810333252
# (launch_and_fit pid=9284) Epoch 18: train loss 3054.6533126831055
# (launch_and_fit pid=9746) Epoch 16: train loss 3050.989673614502
# (launch_and_fit pid=9285) Epoch 13: train loss 3067.234718322754
# (launch_and_fit pid=9746) Epoch 17: train loss 3046.6406173706055
# (launch_and_fit pid=9284) Epoch 19: train loss 3052.4138107299805
# (launch_and_fit pid=9746) Epoch 18: train loss 3044.8756408691406
# (launch_and_fit pid=9746) Epoch 19: train loss 3040.6154708862305
# (launch_and_fit pid=9285) Epoch 14: train loss 3060.41943359375
# (launch_and_fit pid=9284) Epoch 20: train loss 3048.1597785949707
# (launch_and_fit pid=9746) Epoch 20: train loss 3036.255588531494
# (launch_and_fit pid=9285) Epoch 15: train loss 3065.371639251709
# (launch_and_fit pid=9285) Epoch 16: train loss 3059.6116065979004
# (launch_and_fit pid=9285) Epoch 17: train loss 3059.674118041992
# (launch_and_fit pid=9285) Epoch 18: train loss 3056.2036209106445
# (launch_and_fit pid=9285) Epoch 19: train loss 3050.7597465515137
# (launch_and_fit pid=9285) Epoch 20: train loss 3048.8268661499023
# (launch_and_fit pid=9284) Epoch 1: train loss 3015.6463012695312
# (launch_and_fit pid=9284) Epoch 2: train loss 3013.4749717712402
# (launch_and_fit pid=9285) Epoch 1: train loss 3099.667339324951
# (launch_and_fit pid=9284) Epoch 3: train loss 3007.4892768859863
# (launch_and_fit pid=9285) Epoch 2: train loss 3095.4483222961426
# (launch_and_fit pid=9284) Epoch 4: train loss 3004.7412033081055
# (launch_and_fit pid=9285) Epoch 3: train loss 3092.3386726379395
# (launch_and_fit pid=9284) Epoch 5: train loss 3002.980197906494
# (launch_and_fit pid=9285) Epoch 4: train loss 3090.6190185546875
# (launch_and_fit pid=9284) Epoch 6: train loss 3001.0174102783203
# (launch_and_fit pid=9284) Epoch 7: train loss 2998.4182624816895
# (launch_and_fit pid=9285) Epoch 5: train loss 3087.0230102539062
# (launch_and_fit pid=9284) Epoch 8: train loss 2993.481876373291
# (launch_and_fit pid=9285) Epoch 6: train loss 3082.4722213745117
# (launch_and_fit pid=9284) Epoch 9: train loss 2992.6730003356934
# (launch_and_fit pid=9285) Epoch 7: train loss 3080.8693656921387
# (launch_and_fit pid=9284) Epoch 10: train loss 2987.2486457824707
# (launch_and_fit pid=9285) Epoch 8: train loss 3072.62215423584
# (launch_and_fit pid=9284) Epoch 11: train loss 2986.8789405822754
# (launch_and_fit pid=9285) Epoch 9: train loss 3073.1565437316895
# (launch_and_fit pid=9284) Epoch 12: train loss 2981.52449798584
# (launch_and_fit pid=9285) Epoch 10: train loss 3071.011947631836
# (launch_and_fit pid=9284) Epoch 13: train loss 2980.7560234069824
# (launch_and_fit pid=9284) Epoch 14: train loss 2974.8531913757324
# (launch_and_fit pid=9285) Epoch 11: train loss 3070.7491874694824
# (launch_and_fit pid=9285) Epoch 12: train loss 3064.942310333252
# (launch_and_fit pid=9284) Epoch 15: train loss 2975.2978858947754
# (launch_and_fit pid=9285) Epoch 13: train loss 3067.664478302002
# (launch_and_fit pid=9284) Epoch 16: train loss 2970.8945922851562
# (launch_and_fit pid=9284) Epoch 17: train loss 2968.368480682373
# (launch_and_fit pid=9285) Epoch 14: train loss 3060.383403778076
# (launch_and_fit pid=9284) Epoch 18: train loss 2965.124465942383
# (launch_and_fit pid=9284) Epoch 19: train loss 2961.7113723754883
# (launch_and_fit pid=9285) Epoch 15: train loss 3061.7347984313965
# (launch_and_fit pid=9284) Epoch 20: train loss 2960.6408081054688
# (launch_and_fit pid=9285) Epoch 16: train loss 3057.2876052856445
# (launch_and_fit pid=9746) Epoch 1: train loss 3051.049388885498
# (launch_and_fit pid=9285) Epoch 17: train loss 3050.2774353027344
# (launch_and_fit pid=9746) Epoch 2: train loss 3051.4359092712402
# (launch_and_fit pid=9285) Epoch 18: train loss 3049.926280975342
# (launch_and_fit pid=9746) Epoch 3: train loss 3042.7442893981934
# (launch_and_fit pid=9285) Epoch 19: train loss 3049.2631340026855
# (launch_and_fit pid=9746) Epoch 4: train loss 3041.504177093506
# (launch_and_fit pid=9285) Epoch 20: train loss 3044.2960815429688
# (launch_and_fit pid=9746) Epoch 5: train loss 3040.071128845215
# (launch_and_fit pid=9746) Epoch 6: train loss 3039.438056945801
# (launch_and_fit pid=9746) Epoch 7: train loss 3031.7986450195312
# (launch_and_fit pid=9746) Epoch 8: train loss 3027.1154861450195
# (launch_and_fit pid=9746) Epoch 9: train loss 3026.8689918518066
# (launch_and_fit pid=9746) Epoch 10: train loss 3026.6017837524414
# (launch_and_fit pid=9746) Epoch 11: train loss 3022.208019256592
# (launch_and_fit pid=9746) Epoch 12: train loss 3019.8386039733887
# (launch_and_fit pid=9746) Epoch 13: train loss 3017.5200004577637
# (launch_and_fit pid=9746) Epoch 14: train loss 3014.830997467041
# (launch_and_fit pid=9746) Epoch 15: train loss 3009.1538124084473
# (launch_and_fit pid=9746) Epoch 16: train loss 3006.245101928711
# (launch_and_fit pid=9746) Epoch 17: train loss 3004.268829345703
# (launch_and_fit pid=9746) Epoch 18: train loss 3001.1022300720215
# (launch_and_fit pid=9746) Epoch 19: train loss 3002.205276489258
# (launch_and_fit pid=9746) Epoch 20: train loss 2999.386863708496
# (launch_and_fit pid=9285) Epoch 1: train loss 3074.4887084960938
# (launch_and_fit pid=9285) Epoch 2: train loss 3075.6858520507812
# (launch_and_fit pid=9285) Epoch 3: train loss 3068.522548675537
# (launch_and_fit pid=9285) Epoch 4: train loss 3067.377586364746
# (launch_and_fit pid=9285) Epoch 5: train loss 3063.1469078063965
# (launch_and_fit pid=9285) Epoch 6: train loss 3063.284725189209
# (launch_and_fit pid=9285) Epoch 7: train loss 3055.441638946533
# (launch_and_fit pid=9284) Epoch 1: train loss 3113.214530944824
# (launch_and_fit pid=9285) Epoch 8: train loss 3053.192184448242
# (launch_and_fit pid=9284) Epoch 2: train loss 3106.36519241333
# (launch_and_fit pid=9285) Epoch 9: train loss 3049.7257118225098
# (launch_and_fit pid=9285) Epoch 10: train loss 3047.529628753662
# (launch_and_fit pid=9284) Epoch 3: train loss 3103.508155822754
# (launch_and_fit pid=9285) Epoch 11: train loss 3042.9789237976074
# (launch_and_fit pid=9284) Epoch 4: train loss 3104.812526702881
# (launch_and_fit pid=9285) Epoch 12: train loss 3044.950481414795
# (launch_and_fit pid=9284) Epoch 5: train loss 3101.5304412841797
# (launch_and_fit pid=9285) Epoch 13: train loss 3041.970302581787
# (launch_and_fit pid=9284) Epoch 6: train loss 3094.1208839416504
# (launch_and_fit pid=9285) Epoch 14: train loss 3037.563766479492
# (launch_and_fit pid=9284) Epoch 7: train loss 3094.0282135009766
# (launch_and_fit pid=9285) Epoch 15: train loss 3032.1550064086914
# (launch_and_fit pid=9284) Epoch 8: train loss 3092.1356620788574
# (launch_and_fit pid=9285) Epoch 16: train loss 3032.125835418701
# (launch_and_fit pid=9284) Epoch 9: train loss 3086.5078315734863
# (launch_and_fit pid=9285) Epoch 17: train loss 3030.6107292175293
# (launch_and_fit pid=9284) Epoch 10: train loss 3087.152542114258
# (launch_and_fit pid=9285) Epoch 18: train loss 3027.390121459961
# (launch_and_fit pid=9284) Epoch 11: train loss 3084.1753730773926
# (launch_and_fit pid=9746) Epoch 1: train loss 3108.4534187316895
# (launch_and_fit pid=9285) Epoch 19: train loss 3025.280002593994
# (launch_and_fit pid=9284) Epoch 12: train loss 3078.529624938965
# (launch_and_fit pid=9746) Epoch 2: train loss 3107.3993186950684
# (launch_and_fit pid=9285) Epoch 20: train loss 3020.140712738037
# (launch_and_fit pid=9284) Epoch 13: train loss 3074.0498390197754
# (launch_and_fit pid=9746) Epoch 3: train loss 3103.553943634033
# (launch_and_fit pid=9284) Epoch 14: train loss 3073.372871398926
# (launch_and_fit pid=9746) Epoch 4: train loss 3098.8435096740723
# (launch_and_fit pid=9284) Epoch 15: train loss 3070.8330612182617
# (launch_and_fit pid=9746) Epoch 5: train loss 3098.8183670043945
# (launch_and_fit pid=9284) Epoch 16: train loss 3068.986526489258
# (launch_and_fit pid=9746) Epoch 6: train loss 3091.8379707336426
# (launch_and_fit pid=9284) Epoch 17: train loss 3062.8856887817383
# (launch_and_fit pid=9746) Epoch 7: train loss 3091.2752227783203
# (launch_and_fit pid=9284) Epoch 18: train loss 3063.0790519714355
# (launch_and_fit pid=9746) Epoch 8: train loss 3088.854595184326
# (launch_and_fit pid=9284) Epoch 19: train loss 3062.4266395568848
# (launch_and_fit pid=9746) Epoch 9: train loss 3082.12788772583
# (launch_and_fit pid=9284) Epoch 20: train loss 3060.219741821289
# (launch_and_fit pid=9746) Epoch 10: train loss 3083.8241806030273
# (launch_and_fit pid=9746) Epoch 11: train loss 3076.06734085083
# (launch_and_fit pid=9746) Epoch 12: train loss 3078.7256660461426
# (launch_and_fit pid=9746) Epoch 13: train loss 3076.9351959228516
# (launch_and_fit pid=9746) Epoch 14: train loss 3071.259552001953
# (launch_and_fit pid=9746) Epoch 15: train loss 3071.9426345825195
# (launch_and_fit pid=9746) Epoch 16: train loss 3065.0795822143555
# (launch_and_fit pid=9746) Epoch 17: train loss 3064.545738220215
# (launch_and_fit pid=9746) Epoch 18: train loss 3060.51123046875
# (launch_and_fit pid=9746) Epoch 19: train loss 3060.0861434936523
# (launch_and_fit pid=9746) Epoch 20: train loss 3056.614501953125
# (launch_and_fit pid=9746) Epoch 1: train loss 3136.1129302978516
# (launch_and_fit pid=9746) Epoch 2: train loss 3129.369186401367
# (launch_and_fit pid=9746) Epoch 3: train loss 3124.8240966796875
# (launch_and_fit pid=9746) Epoch 4: train loss 3124.4496726989746
# (launch_and_fit pid=9746) Epoch 5: train loss 3121.6858711242676
# (launch_and_fit pid=9746) Epoch 6: train loss 3118.5451622009277
# (launch_and_fit pid=9746) Epoch 7: train loss 3116.515857696533
# (launch_and_fit pid=9746) Epoch 8: train loss 3111.2236251831055
# (launch_and_fit pid=9746) Epoch 9: train loss 3108.5305519104004
# (launch_and_fit pid=9746) Epoch 10: train loss 3109.8536376953125
# (launch_and_fit pid=9746) Epoch 11: train loss 3103.493324279785
# (launch_and_fit pid=9746) Epoch 12: train loss 3102.84916305542
# (launch_and_fit pid=9746) Epoch 13: train loss 3098.6737327575684
# (launch_and_fit pid=9746) Epoch 14: train loss 3101.6603050231934
# (launch_and_fit pid=9746) Epoch 15: train loss 3096.7699241638184
# (launch_and_fit pid=9746) Epoch 16: train loss 3090.950126647949
# (launch_and_fit pid=9746) Epoch 17: train loss 3087.231575012207
# (launch_and_fit pid=9746) Epoch 18: train loss 3085.607940673828
# (launch_and_fit pid=9746) Epoch 19: train loss 3086.237861633301
# DEBUG flwr 2023-04-25 03:39:56,437 | server.py:232 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# DEBUG flwr 2023-04-25 03:39:56,511 | server.py:168 | evaluate_round 2: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 2: strategy sampled 5 clients (out of 10)
# (launch_and_fit pid=9746) Epoch 20: train loss 3081.3904762268066
# (launch_and_evaluate pid=9284) Eval RMSE: 9425.03857421875: 12
# (launch_and_evaluate pid=9746) Eval RMSE: 9392.460205078125: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9413.719401041666: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9441.836832682291: 12
# DEBUG flwr 2023-04-25 03:40:57,038 | server.py:182 | evaluate_round 2 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 2 received 5 results and 0 failures
# DEBUG flwr 2023-04-25 03:40:57,044 | server.py:218 | fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 10)
# (launch_and_evaluate pid=9284) Eval RMSE: 9440.788899739584: 12
# (launch_and_fit pid=9284) Epoch 1: train loss 3076.816963195801
# (launch_and_fit pid=9284) Epoch 2: train loss 3074.3799781799316
# (launch_and_fit pid=9746) Epoch 1: train loss 3046.574405670166
# (launch_and_fit pid=9284) Epoch 3: train loss 3072.2566719055176
# (launch_and_fit pid=9746) Epoch 2: train loss 3045.3211059570312
# (launch_and_fit pid=9284) Epoch 4: train loss 3071.8006439208984
# (launch_and_fit pid=9285) Epoch 1: train loss 3054.609245300293
# (launch_and_fit pid=9284) Epoch 5: train loss 3065.8556175231934
# (launch_and_fit pid=9746) Epoch 3: train loss 3043.715301513672
# (launch_and_fit pid=9284) Epoch 6: train loss 3066.0982971191406
# (launch_and_fit pid=9285) Epoch 2: train loss 3050.8631439208984
# (launch_and_fit pid=9284) Epoch 7: train loss 3065.1944427490234
# (launch_and_fit pid=9746) Epoch 4: train loss 3038.4505615234375
# (launch_and_fit pid=9284) Epoch 8: train loss 3060.3041458129883
# (launch_and_fit pid=9746) Epoch 5: train loss 3036.3701133728027
# (launch_and_fit pid=9285) Epoch 3: train loss 3053.9655685424805
# (launch_and_fit pid=9746) Epoch 6: train loss 3033.463367462158
# (launch_and_fit pid=9285) Epoch 4: train loss 3049.638156890869
# (launch_and_fit pid=9284) Epoch 9: train loss 3055.59268951416
# (launch_and_fit pid=9285) Epoch 5: train loss 3044.64546585083
# (launch_and_fit pid=9284) Epoch 10: train loss 3054.238380432129
# (launch_and_fit pid=9746) Epoch 7: train loss 3036.693347930908
# (launch_and_fit pid=9284) Epoch 11: train loss 3050.767505645752
# (launch_and_fit pid=9285) Epoch 6: train loss 3039.2715225219727
# (launch_and_fit pid=9746) Epoch 8: train loss 3029.242012023926
# (launch_and_fit pid=9284) Epoch 12: train loss 3048.9970321655273
# (launch_and_fit pid=9285) Epoch 7: train loss 3036.0971069335938
# (launch_and_fit pid=9746) Epoch 9: train loss 3025.7363662719727
# (launch_and_fit pid=9284) Epoch 13: train loss 3047.4192237854004
# (launch_and_fit pid=9285) Epoch 8: train loss 3040.4248809814453
# (launch_and_fit pid=9284) Epoch 14: train loss 3043.461456298828
# (launch_and_fit pid=9746) Epoch 10: train loss 3021.98783493042
# (launch_and_fit pid=9285) Epoch 9: train loss 3036.276195526123
# (launch_and_fit pid=9284) Epoch 15: train loss 3043.2156410217285
# (launch_and_fit pid=9285) Epoch 10: train loss 3034.242446899414
# (launch_and_fit pid=9284) Epoch 16: train loss 3041.5255966186523
# (launch_and_fit pid=9284) Epoch 17: train loss 3036.648391723633
# (launch_and_fit pid=9746) Epoch 11: train loss 3018.727363586426
# (launch_and_fit pid=9285) Epoch 11: train loss 3027.0601539611816
# (launch_and_fit pid=9285) Epoch 12: train loss 3024.89852142334
# (launch_and_fit pid=9284) Epoch 18: train loss 3036.621311187744
# (launch_and_fit pid=9746) Epoch 12: train loss 3018.2989959716797
# (launch_and_fit pid=9285) Epoch 13: train loss 3023.482334136963
# (launch_and_fit pid=9746) Epoch 13: train loss 3018.9134788513184
# (launch_and_fit pid=9285) Epoch 14: train loss 3023.7857208251953
# (launch_and_fit pid=9284) Epoch 19: train loss 3032.9648475646973
# (launch_and_fit pid=9746) Epoch 14: train loss 3013.2485389709473
# (launch_and_fit pid=9284) Epoch 20: train loss 3032.2709770202637
# (launch_and_fit pid=9285) Epoch 15: train loss 3021.9093055725098
# (launch_and_fit pid=9285) Epoch 16: train loss 3015.8894538879395
# (launch_and_fit pid=9746) Epoch 15: train loss 3012.083885192871
# (launch_and_fit pid=9285) Epoch 17: train loss 3013.995090484619
# (launch_and_fit pid=9746) Epoch 16: train loss 3008.1484336853027
# (launch_and_fit pid=9285) Epoch 18: train loss 3010.4426612854004
# (launch_and_fit pid=9746) Epoch 17: train loss 3008.6448364257812
# (launch_and_fit pid=9285) Epoch 19: train loss 3014.4458045959473
# (launch_and_fit pid=9746) Epoch 18: train loss 3004.216522216797
# (launch_and_fit pid=9285) Epoch 20: train loss 3003.380516052246
# (launch_and_fit pid=9746) Epoch 19: train loss 3003.005813598633
# (launch_and_fit pid=9746) Epoch 20: train loss 3004.335693359375
# (launch_and_fit pid=9285) Epoch 1: train loss 3043.2693099975586
# (launch_and_fit pid=9285) Epoch 2: train loss 3040.384220123291
# (launch_and_fit pid=9285) Epoch 3: train loss 3043.537784576416
# (launch_and_fit pid=9746) Epoch 1: train loss 2995.2782287597656
# (launch_and_fit pid=9746) Epoch 2: train loss 2991.2701110839844
# (launch_and_fit pid=9285) Epoch 4: train loss 3036.7402381896973
# (launch_and_fit pid=9746) Epoch 3: train loss 2987.495880126953
# (launch_and_fit pid=9285) Epoch 5: train loss 3032.6461181640625
# (launch_and_fit pid=9746) Epoch 4: train loss 2990.034278869629
# (launch_and_fit pid=9285) Epoch 6: train loss 3036.563808441162
# (launch_and_fit pid=9746) Epoch 5: train loss 2986.098876953125
# (launch_and_fit pid=9285) Epoch 7: train loss 3032.0772972106934
# (launch_and_fit pid=9746) Epoch 6: train loss 2982.742115020752
# (launch_and_fit pid=9285) Epoch 8: train loss 3027.914562225342
# (launch_and_fit pid=9285) Epoch 9: train loss 3027.456287384033
# (launch_and_fit pid=9746) Epoch 7: train loss 2981.9483947753906
# (launch_and_fit pid=9285) Epoch 10: train loss 3025.654716491699
# (launch_and_fit pid=9746) Epoch 8: train loss 2979.306827545166
# (launch_and_fit pid=9285) Epoch 11: train loss 3022.4110221862793
# (launch_and_fit pid=9746) Epoch 9: train loss 2975.4806900024414
# (launch_and_fit pid=9285) Epoch 12: train loss 3017.0860633850098
# (launch_and_fit pid=9746) Epoch 10: train loss 2969.665283203125
# (launch_and_fit pid=9285) Epoch 13: train loss 3016.3906478881836
# (launch_and_fit pid=9285) Epoch 14: train loss 3015.0531425476074
# (launch_and_fit pid=9746) Epoch 11: train loss 2972.2825050354004
# (launch_and_fit pid=9285) Epoch 15: train loss 3013.03568649292
# (launch_and_fit pid=9746) Epoch 12: train loss 2967.030990600586
# (launch_and_fit pid=9285) Epoch 16: train loss 3010.9202041625977
# (launch_and_fit pid=9746) Epoch 13: train loss 2966.5101051330566
# (launch_and_fit pid=9285) Epoch 17: train loss 3008.492500305176
# (launch_and_fit pid=9746) Epoch 14: train loss 2964.8425827026367
# (launch_and_fit pid=9285) Epoch 18: train loss 3003.860866546631
# (launch_and_fit pid=9746) Epoch 15: train loss 2963.8506622314453
# (launch_and_fit pid=9746) Epoch 16: train loss 2960.1228370666504
# (launch_and_fit pid=9285) Epoch 19: train loss 3005.8082885742188
# (launch_and_fit pid=9746) Epoch 17: train loss 2956.818458557129
# (launch_and_fit pid=9285) Epoch 20: train loss 2998.4732551574707
# (launch_and_fit pid=9746) Epoch 18: train loss 2954.592700958252
# (launch_and_fit pid=9746) Epoch 19: train loss 2951.741958618164
# (launch_and_fit pid=9746) Epoch 20: train loss 2948.5896606445312
# (launch_and_fit pid=9284) Epoch 1: train loss 2959.4483032226562
# (launch_and_fit pid=9284) Epoch 2: train loss 2957.026054382324
# (launch_and_fit pid=9284) Epoch 3: train loss 2952.672763824463
# (launch_and_fit pid=9284) Epoch 4: train loss 2948.8274879455566
# (launch_and_fit pid=9284) Epoch 5: train loss 2946.6368255615234
# (launch_and_fit pid=9284) Epoch 6: train loss 2945.8471717834473
# (launch_and_fit pid=9284) Epoch 7: train loss 2941.266311645508
# (launch_and_fit pid=9284) Epoch 8: train loss 2942.7323303222656
# (launch_and_fit pid=9284) Epoch 9: train loss 2935.997730255127
# (launch_and_fit pid=9284) Epoch 10: train loss 2934.3619384765625
# (launch_and_fit pid=9284) Epoch 11: train loss 2933.764133453369
# (launch_and_fit pid=9284) Epoch 12: train loss 2931.1087951660156
# (launch_and_fit pid=9284) Epoch 13: train loss 2927.681755065918
# (launch_and_fit pid=9284) Epoch 14: train loss 2921.7609519958496
# (launch_and_fit pid=9284) Epoch 15: train loss 2919.5610542297363
# (launch_and_fit pid=9284) Epoch 16: train loss 2917.1091651916504
# (launch_and_fit pid=9284) Epoch 17: train loss 2916.3647994995117
# (launch_and_fit pid=9284) Epoch 18: train loss 2911.759532928467
# (launch_and_fit pid=9284) Epoch 19: train loss 2914.480293273926
# (launch_and_fit pid=9284) Epoch 20: train loss 2906.529640197754
# (launch_and_fit pid=9746) Epoch 1: train loss 3016.891372680664
# (launch_and_fit pid=9746) Epoch 2: train loss 3014.2070922851562
# (launch_and_fit pid=9746) Epoch 3: train loss 3012.8833541870117
# (launch_and_fit pid=9746) Epoch 4: train loss 3010.92520904541
# (launch_and_fit pid=9746) Epoch 5: train loss 3005.9464416503906
# (launch_and_fit pid=9746) Epoch 6: train loss 3003.9444465637207
# (launch_and_fit pid=9284) Epoch 1: train loss 3033.40771484375
# (launch_and_fit pid=9746) Epoch 7: train loss 3004.9718704223633
# (launch_and_fit pid=9284) Epoch 2: train loss 3033.6348190307617
# (launch_and_fit pid=9746) Epoch 8: train loss 3000.4564056396484
# (launch_and_fit pid=9284) Epoch 3: train loss 3026.2958068847656
# (launch_and_fit pid=9746) Epoch 9: train loss 2997.587715148926
# (launch_and_fit pid=9284) Epoch 4: train loss 3029.4569129943848
# (launch_and_fit pid=9284) Epoch 5: train loss 3027.8627738952637
# (launch_and_fit pid=9746) Epoch 10: train loss 2993.8336067199707
# (launch_and_fit pid=9746) Epoch 11: train loss 2993.2691078186035
# (launch_and_fit pid=9284) Epoch 6: train loss 3023.528537750244
# (launch_and_fit pid=9284) Epoch 7: train loss 3017.945285797119
# (launch_and_fit pid=9746) Epoch 12: train loss 2988.5942878723145
# (launch_and_fit pid=9746) Epoch 13: train loss 2988.2670402526855
# (launch_and_fit pid=9284) Epoch 8: train loss 3017.9707260131836
# (launch_and_fit pid=9284) Epoch 9: train loss 3013.948024749756
# (launch_and_fit pid=9746) Epoch 14: train loss 2985.037364959717
# (launch_and_fit pid=9284) Epoch 10: train loss 3009.853199005127
# (launch_and_fit pid=9746) Epoch 15: train loss 2976.221839904785
# (launch_and_fit pid=9746) Epoch 16: train loss 2978.536449432373
# (launch_and_fit pid=9284) Epoch 11: train loss 3005.1664848327637
# (launch_and_fit pid=9746) Epoch 17: train loss 2978.5383911132812
# (launch_and_fit pid=9284) Epoch 12: train loss 3008.444683074951
# (launch_and_fit pid=9746) Epoch 18: train loss 2974.384738922119
# (launch_and_fit pid=9284) Epoch 13: train loss 3001.323287963867
# (launch_and_fit pid=9746) Epoch 19: train loss 2976.4242401123047
# (launch_and_fit pid=9284) Epoch 14: train loss 3002.269088745117
# (launch_and_fit pid=9746) Epoch 20: train loss 2971.9528198242188
# (launch_and_fit pid=9284) Epoch 15: train loss 3000.3201332092285
# (launch_and_fit pid=9284) Epoch 16: train loss 2994.794589996338
# (launch_and_fit pid=9284) Epoch 17: train loss 2994.299060821533
# (launch_and_fit pid=9284) Epoch 18: train loss 2992.8072242736816
# (launch_and_fit pid=9284) Epoch 19: train loss 2992.203239440918
# (launch_and_fit pid=9284) Epoch 20: train loss 2989.58113861084
# (launch_and_fit pid=9284) Epoch 1: train loss 3042.3355598449707
# (launch_and_fit pid=9284) Epoch 2: train loss 3042.8892669677734
# (launch_and_fit pid=9284) Epoch 3: train loss 3038.8991622924805
# (launch_and_fit pid=9284) Epoch 4: train loss 3036.9187965393066
# (launch_and_fit pid=9284) Epoch 5: train loss 3032.306079864502
# (launch_and_fit pid=9284) Epoch 6: train loss 3032.274040222168
# (launch_and_fit pid=9284) Epoch 7: train loss 3027.310272216797
# (launch_and_fit pid=9284) Epoch 8: train loss 3024.666358947754
# (launch_and_fit pid=9284) Epoch 9: train loss 3020.066005706787
# (launch_and_fit pid=9284) Epoch 10: train loss 3018.9197311401367
# (launch_and_fit pid=9284) Epoch 11: train loss 3019.9412994384766
# (launch_and_fit pid=9284) Epoch 12: train loss 3017.0018157958984
# (launch_and_fit pid=9284) Epoch 13: train loss 3011.0409545898438
# (launch_and_fit pid=9284) Epoch 14: train loss 3011.1420860290527
# (launch_and_fit pid=9284) Epoch 15: train loss 3007.7333183288574
# (launch_and_fit pid=9284) Epoch 16: train loss 3007.5279502868652
# (launch_and_fit pid=9284) Epoch 17: train loss 3002.2023849487305
# (launch_and_fit pid=9284) Epoch 18: train loss 2999.9449729919434
# (launch_and_fit pid=9284) Epoch 19: train loss 3001.032314300537
# (launch_and_fit pid=9284) Epoch 20: train loss 2997.7703399658203
# (launch_and_fit pid=9284) Epoch 1: train loss 3053.452983856201
# (launch_and_fit pid=9284) Epoch 2: train loss 3050.130340576172
# (launch_and_fit pid=9284) Epoch 3: train loss 3044.043857574463
# (launch_and_fit pid=9284) Epoch 4: train loss 3045.099826812744
# (launch_and_fit pid=9284) Epoch 5: train loss 3042.9016647338867
# (launch_and_fit pid=9284) Epoch 6: train loss 3041.4274673461914
# (launch_and_fit pid=9284) Epoch 7: train loss 3038.3306007385254
# (launch_and_fit pid=9284) Epoch 8: train loss 3032.6841163635254
# (launch_and_fit pid=9284) Epoch 9: train loss 3035.0514183044434
# (launch_and_fit pid=9284) Epoch 10: train loss 3031.623977661133
# (launch_and_fit pid=9284) Epoch 11: train loss 3028.328227996826
# (launch_and_fit pid=9284) Epoch 12: train loss 3024.6267127990723
# (launch_and_fit pid=9284) Epoch 13: train loss 3023.554862976074
# (launch_and_fit pid=9284) Epoch 14: train loss 3016.9625282287598
# (launch_and_fit pid=9284) Epoch 15: train loss 3020.4521446228027
# (launch_and_fit pid=9284) Epoch 16: train loss 3013.387725830078
# (launch_and_fit pid=9284) Epoch 17: train loss 3010.602695465088
# (launch_and_fit pid=9284) Epoch 18: train loss 3012.6438789367676
# (launch_and_fit pid=9284) Epoch 19: train loss 3011.192897796631
# DEBUG flwr 2023-04-25 03:43:15,818 | server.py:232 | fit_round 3 received 10 results and 0 failures
# DEBUG:flwr:fit_round 3 received 10 results and 0 failures
# DEBUG flwr 2023-04-25 03:43:15,862 | server.py:168 | evaluate_round 3: strategy sampled 5 clients (out of 10)
# DEBUG:flwr:evaluate_round 3: strategy sampled 5 clients (out of 10)
# (launch_and_fit pid=9284) Epoch 20: train loss 3008.3146629333496
# (launch_and_evaluate pid=9284) Eval RMSE: 9274.417643229166: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9344.201416015625: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9289.985921223959: 12
# (launch_and_evaluate pid=9284) Eval RMSE: 9307.071695963541: 12
# DEBUG flwr 2023-04-25 03:44:16,635 | server.py:182 | evaluate_round 3 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 3 received 5 results and 0 failures
# DEBUG flwr 2023-04-25 03:44:16,644 | server.py:218 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG:flwr:fit_round 4: strategy sampled 10 clients (out of 10)
# (launch_and_evaluate pid=9284) Eval RMSE: 9299.007405598959: 12
# (launch_and_fit pid=9284) Epoch 1: train loss 3026.776008605957
# (launch_and_fit pid=9284) Epoch 2: train loss 3023.3914680480957
# (launch_and_fit pid=9284) Epoch 3: train loss 3023.8887481689453
# (launch_and_fit pid=9746) Epoch 1: train loss 3000.969081878662
# (launch_and_fit pid=9746) Epoch 2: train loss 2998.017044067383
# (launch_and_fit pid=9746) Epoch 3: train loss 2994.801471710205
# (launch_and_fit pid=9746) Epoch 4: train loss 2993.069995880127
# (launch_and_fit pid=9746) Epoch 5: train loss 2989.9167518615723
# (launch_and_fit pid=9746) Epoch 6: train loss 2986.2281188964844
# (launch_and_fit pid=9746) Epoch 7: train loss 2983.5580139160156
# (launch_and_fit pid=9285) Epoch 1: train loss 2965.5199584960938
# (launch_and_fit pid=9746) Epoch 8: train loss 2982.4528846740723
# (launch_and_fit pid=9285) Epoch 2: train loss 2966.726047515869
# (launch_and_fit pid=9746) Epoch 9: train loss 2979.912654876709
# (launch_and_fit pid=9285) Epoch 3: train loss 2963.4591217041016
# (launch_and_fit pid=9746) Epoch 10: train loss 2977.6869468688965
# (launch_and_fit pid=9284) Epoch 4: train loss 3021.1849098205566
# (launch_and_fit pid=9285) Epoch 4: train loss 2959.784252166748
# (launch_and_fit pid=9746) Epoch 11: train loss 2976.677665710449
# (launch_and_fit pid=9285) Epoch 5: train loss 2962.1382789611816
# (launch_and_fit pid=9284) Epoch 5: train loss 3019.814407348633
# (launch_and_fit pid=9746) Epoch 12: train loss 2976.561897277832
# (launch_and_fit pid=9285) Epoch 6: train loss 2955.9346313476562
# (launch_and_fit pid=9746) Epoch 13: train loss 2974.8181190490723
# (launch_and_fit pid=9284) Epoch 6: train loss 3016.438720703125
# (launch_and_fit pid=9285) Epoch 7: train loss 2957.089214324951
# (launch_and_fit pid=9285) Epoch 8: train loss 2952.715476989746
# (launch_and_fit pid=9746) Epoch 14: train loss 2969.926540374756
# (launch_and_fit pid=9284) Epoch 7: train loss 3015.9139709472656
# (launch_and_fit pid=9746) Epoch 15: train loss 2965.569808959961
# (launch_and_fit pid=9285) Epoch 9: train loss 2950.0057792663574
# (launch_and_fit pid=9746) Epoch 16: train loss 2964.782527923584
# (launch_and_fit pid=9284) Epoch 8: train loss 3016.232563018799
# (launch_and_fit pid=9285) Epoch 10: train loss 2947.098434448242
# (launch_and_fit pid=9284) Epoch 9: train loss 3008.2681465148926
# (launch_and_fit pid=9746) Epoch 17: train loss 2961.7106895446777
# (launch_and_fit pid=9285) Epoch 11: train loss 2943.3916778564453
# (launch_and_fit pid=9746) Epoch 18: train loss 2960.222885131836
# (launch_and_fit pid=9284) Epoch 10: train loss 3009.650562286377
# (launch_and_fit pid=9285) Epoch 12: train loss 2941.0501556396484
# (launch_and_fit pid=9284) Epoch 11: train loss 3007.9327964782715
# (launch_and_fit pid=9746) Epoch 19: train loss 2960.7195472717285
# (launch_and_fit pid=9746) Epoch 20: train loss 2951.9326248168945
# (launch_and_fit pid=9285) Epoch 13: train loss 2941.907257080078
# (launch_and_fit pid=9284) Epoch 12: train loss 3003.7698707580566
# (launch_and_fit pid=9285) Epoch 14: train loss 2940.310375213623
# (launch_and_fit pid=9285) Epoch 15: train loss 2935.969169616699
# (launch_and_fit pid=9284) Epoch 13: train loss 2999.2120056152344
# (launch_and_fit pid=9285) Epoch 16: train loss 2935.4549446105957
# (launch_and_fit pid=9284) Epoch 14: train loss 3000.6141052246094
# (launch_and_fit pid=9285) Epoch 17: train loss 2932.6207160949707
# (launch_and_fit pid=9284) Epoch 15: train loss 2999.9622840881348
# ...
# (launch_and_fit pid=9285) Epoch 20: train loss 2745.1962394714355
# (launch_and_evaluate pid=9285) Eval RMSE: 8631.211181640625: 12
# (launch_and_evaluate pid=9746) Eval RMSE: 8590.212890625: 12
# (launch_and_evaluate pid=9285) Eval RMSE: 8608.835042317709: 12
# DEBUG flwr 2023-04-25 04:07:05,226 | server.py:182 | evaluate_round 10 received 5 results and 0 failures
# DEBUG:flwr:evaluate_round 10 received 5 results and 0 failures
# INFO flwr 2023-04-25 04:07:05,235 | server.py:147 | FL finished in 2005.2884636100002
# INFO:flwr:FL finished in 2005.2884636100002
# INFO flwr 2023-04-25 04:07:05,241 | app.py:218 | app_fit: losses_distributed [(1, 8840.326953125), (2, 8697.940414663462), (3, 8587.326292067308), (4, 8457.14178936298), (5, 8358.468592247596), (6, 8244.745057091346), (7, 8171.637447415866), (8, 8081.7839918870195), (9, 8028.708255709134), (10, 7942.157677283654)]
# INFO:flwr:app_fit: losses_distributed [(1, 8840.326953125), (2, 8697.940414663462), (3, 8587.326292067308), (4, 8457.14178936298), (5, 8358.468592247596), (6, 8244.745057091346), (7, 8171.637447415866), (8, 8081.7839918870195), (9, 8028.708255709134), (10, 7942.157677283654)]
# INFO flwr 2023-04-25 04:07:05,249 | app.py:219 | app_fit: metrics_distributed_fit {'client_metrics': [(1, {'loss': [3082.7908168792724, 3133.8892538070677, 3123.068593788147, 3106.160990333557, 3048.783815383911, 3129.530735206604, 3165.293577003479, 3143.3678747177123, 3141.0879323959352, 3134.8147916793823]}), (2, {'loss': [3075.068012237549, 3063.7881549835206, 3106.798751068115, 3047.6780687332152, 3084.096719932556, 3023.7693796157837, 2987.161070251465, 3075.4033926010134, 3071.0876655578613, 3081.83780002594]}), (3, {'loss': [2993.643689727783, 3030.966164779663, 3022.8888010025025, 3029.240629577637, 3023.3588989257814, 3053.8214906692506, 3010.75563659668, 2933.2468519210815, 3019.596135520935, 2972.285157394409]}), (4, {'loss': [3007.6010604858398, 2975.8726457595826, 2984.9899612426757, 2884.5101861953735, 2926.2579061508177, 2977.476763534546, 2946.6552490234376, 2983.139274978638, 2974.876701545715, 2963.186625289917]}), (5, {'loss': [2845.007196998596, 2936.0795080184935, 2933.697172546387, 2936.499471282959, 2904.712560081482, 2965.92062664032, 2943.134303283691, 2886.0117950439453, 2920.5467334747314, 2941.1951139450075]}), (6, {'loss': [2881.937513542175, 2850.0367935180666, 2898.7682662963866, 2898.42599773407, 2867.156736755371, 2905.259620285034, 2804.5337005615233, 2905.1437475204466, 2896.475160598755, 2928.7103830337524]}), (7, {'loss': [2833.680841064453, 2866.936100769043, 2871.2534534454344, 2865.1460540771486, 2869.2737758636476, 2817.6475887298584, 2864.0610641479493, 2772.113506126404, 2895.3248085021974, 2846.585070037842]}), (8, {'loss': [2843.9387086868287, 2863.8635555267333, 2834.957482910156, 2837.4575815200806, 2787.2239904403687, 2803.983536529541, 2741.2544374465942, 2835.2729402542113, 2816.926288795471, 2841.042077064514]}), (9, {'loss': [2759.304501724243, 2814.03651638031, 2789.1827136993406, 2810.0201709747316, 2811.208395195007, 2714.314099121094, 2816.3919591903687, 2778.2055065155027, 2808.5464015960692, 2837.4325246810913]}), (10, {'loss': [2734.7371180534365, 2793.0963418960573, 2789.966576194763, 2765.530487060547, 2784.8273485183718, 2754.4608295440676, 2812.174758148193, 2787.836822128296, 2688.992790603638, 2787.7972087860107]})], 'examples': [(1, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (2, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (3, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (4, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (5, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (6, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (7, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (8, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (9, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (10, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800])], 'average_metrics': [(1, {'average loss': 3120.878838119507}), (2, {'average loss': 3061.668901500702}), (3, {'average loss': 3008.9803456115724}), (4, {'average loss': 2962.4566374206543}), (5, {'average loss': 2921.280448131561}), (6, {'average loss': 2883.644791984558}), (7, {'average loss': 2850.2022262763976}), (8, {'average loss': 2820.59205991745}), (9, {'average loss': 2793.8642789077758}), (10, {'average loss': 2769.942028093338})]}
# INFO:flwr:app_fit: metrics_distributed_fit {'client_metrics': [(1, {'loss': [3082.7908168792724, 3133.8892538070677, 3123.068593788147, 3106.160990333557, 3048.783815383911, 3129.530735206604, 3165.293577003479, 3143.3678747177123, 3141.0879323959352, 3134.8147916793823]}), (2, {'loss': [3075.068012237549, 3063.7881549835206, 3106.798751068115, 3047.6780687332152, 3084.096719932556, 3023.7693796157837, 2987.161070251465, 3075.4033926010134, 3071.0876655578613, 3081.83780002594]}), (3, {'loss': [2993.643689727783, 3030.966164779663, 3022.8888010025025, 3029.240629577637, 3023.3588989257814, 3053.8214906692506, 3010.75563659668, 2933.2468519210815, 3019.596135520935, 2972.285157394409]}), (4, {'loss': [3007.6010604858398, 2975.8726457595826, 2984.9899612426757, 2884.5101861953735, 2926.2579061508177, 2977.476763534546, 2946.6552490234376, 2983.139274978638, 2974.876701545715, 2963.186625289917]}), (5, {'loss': [2845.007196998596, 2936.0795080184935, 2933.697172546387, 2936.499471282959, 2904.712560081482, 2965.92062664032, 2943.134303283691, 2886.0117950439453, 2920.5467334747314, 2941.1951139450075]}), (6, {'loss': [2881.937513542175, 2850.0367935180666, 2898.7682662963866, 2898.42599773407, 2867.156736755371, 2905.259620285034, 2804.5337005615233, 2905.1437475204466, 2896.475160598755, 2928.7103830337524]}), (7, {'loss': [2833.680841064453, 2866.936100769043, 2871.2534534454344, 2865.1460540771486, 2869.2737758636476, 2817.6475887298584, 2864.0610641479493, 2772.113506126404, 2895.3248085021974, 2846.585070037842]}), (8, {'loss': [2843.9387086868287, 2863.8635555267333, 2834.957482910156, 2837.4575815200806, 2787.2239904403687, 2803.983536529541, 2741.2544374465942, 2835.2729402542113, 2816.926288795471, 2841.042077064514]}), (9, {'loss': [2759.304501724243, 2814.03651638031, 2789.1827136993406, 2810.0201709747316, 2811.208395195007, 2714.314099121094, 2816.3919591903687, 2778.2055065155027, 2808.5464015960692, 2837.4325246810913]}), (10, {'loss': [2734.7371180534365, 2793.0963418960573, 2789.966576194763, 2765.530487060547, 2784.8273485183718, 2754.4608295440676, 2812.174758148193, 2787.836822128296, 2688.992790603638, 2787.7972087860107]})], 'examples': [(1, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (2, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (3, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (4, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (5, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (6, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (7, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (8, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (9, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800]), (10, [800, 800, 800, 800, 800, 800, 800, 800, 800, 800])], 'average_metrics': [(1, {'average loss': 3120.878838119507}), (2, {'average loss': 3061.668901500702}), (3, {'average loss': 3008.9803456115724}), (4, {'average loss': 2962.4566374206543}), (5, {'average loss': 2921.280448131561}), (6, {'average loss': 2883.644791984558}), (7, {'average loss': 2850.2022262763976}), (8, {'average loss': 2820.59205991745}), (9, {'average loss': 2793.8642789077758}), (10, {'average loss': 2769.942028093338})]}
# INFO flwr 2023-04-25 04:07:05,255 | app.py:220 | app_fit: metrics_distributed {'average_metrics': [(1, {'valid_mape': 8822.502764423078, 'valid_mae': 8822.502764423078, 'valid_rmse': 8840.326953125}), (2, {'valid_mape': 8679.481265024038, 'valid_mae': 8679.481265024038, 'valid_rmse': 8697.940414663462}), (3, {'valid_mape': 8569.587890625, 'valid_mae': 8569.587890625, 'valid_rmse': 8587.326292067308}), (4, {'valid_mape': 8438.65389873798, 'valid_mae': 8438.65389873798, 'valid_rmse': 8457.14178936298}), (5, {'valid_mape': 8339.997573617788, 'valid_mae': 8339.997573617788, 'valid_rmse': 8358.468592247596}), (6, {'valid_mape': 8225.562545072115, 'valid_mae': 8225.562545072115, 'valid_rmse': 8244.745057091346}), (7, {'valid_mape': 8153.0390474759615, 'valid_mae': 8153.0390474759615, 'valid_rmse': 8171.637447415866}), (8, {'valid_mape': 8062.055003004808, 'valid_mae': 8062.055003004808, 'valid_rmse': 8081.7839918870195}), (9, {'valid_mape': 8008.872160456731, 'valid_mae': 8008.872160456731, 'valid_rmse': 8028.708255709134}), (10, {'valid_mape': 7921.547934194711, 'valid_mae': 7921.547934194711, 'valid_rmse': 7942.157677283654})], 'client_metrics': [(1, {'valid_mape': [8789.794996995191, 8827.326923076924, 8830.306114783654, 8819.991962139424, 8845.093825120191], 'valid_mae': [8789.794996995191, 8827.326923076924, 8830.306114783654, 8819.991962139424, 8845.093825120191], 'valid_rmse': [8808.390700120191, 8844.954552283654, 8848.101712740385, 8837.99676983173, 8862.191030649039], 'examples': [208, 208, 208, 208, 208]}), (2, {'valid_mape': [8681.582106370191, 8698.33135516827, 8649.2744140625, 8696.072490985576, 8672.145958533654], 'valid_mae': [8681.582106370191, 8698.33135516827, 8649.2744140625, 8696.072490985576, 8672.145958533654], 'valid_rmse': [8700.035606971154, 8715.54169170673, 8669.963266225961, 8714.574368990385, 8689.587139423076], 'examples': [208, 208, 208, 208, 208]}), (3, {'valid_mape': [8608.43622295673, 8565.724684495191, 8555.892953725961, 8543.504281850961, 8574.381310096154], 'valid_mae': [8608.43622295673, 8565.724684495191, 8555.892953725961, 8543.504281850961, 8574.381310096154], 'valid_rmse': [8625.41669170673, 8583.699143629809, 8575.371619591346, 8561.000901442309, 8591.143103966346], 'examples': [208, 208, 208, 208, 208]}), (4, {'valid_mape': [8439.398813100961, 8440.654296875, 8487.1982421875, 8414.940091646635, 8411.078049879809], 'valid_mae': [8439.398813100961, 8440.654296875, 8487.1982421875, 8414.940091646635, 8411.078049879809], 'valid_rmse': [8458.746243990385, 8459.055588942309, 8505.30243389423, 8432.92333984375, 8429.68134014423], 'examples': [208, 208, 208, 208, 208]}), (5, {'valid_mape': [8293.300368088941, 8341.05829326923, 8321.608849158654, 8385.367412860576, 8358.652944711539], 'valid_mae': [8293.300368088941, 8341.05829326923, 8321.608849158654, 8385.367412860576, 8358.652944711539], 'valid_rmse': [8315.7275390625, 8358.485501802885, 8340.357797475961, 8402.843299278846, 8374.928823617789], 'examples': [208, 208, 208, 208, 208]}), (6, {'valid_mape': [8188.0154371995195, 8222.440054086539, 8222.74004657452, 8234.109637920674, 8260.507549579326], 'valid_mae': [8188.0154371995195, 8222.440054086539, 8222.74004657452, 8234.109637920674, 8260.507549579326], 'valid_rmse': [8209.862454927885, 8242.134652944711, 8240.651254507211, 8252.532827524039, 8278.544095552885], 'examples': [208, 208, 208, 208, 208]}), (7, {'valid_mape': [8127.845365084135, 8169.417743389423, 8134.768667367788, 8161.282752403846, 8171.880709134615], 'valid_mae': [8127.845365084135, 8169.417743389423, 8134.768667367788, 8161.282752403846, 8171.880709134615], 'valid_rmse': [8147.169546274038, 8188.95263671875, 8153.504544771635, 8179.4753981370195, 8189.085111177885], 'examples': [208, 208, 208, 208, 208]}), (8, {'valid_mape': [8030.912259615385, 8067.811636117788, 8066.0732421875, 8090.463040865385, 8055.0148362379805], 'valid_mae': [8030.912259615385, 8067.811636117788, 8066.0732421875, 8090.463040865385, 8055.0148362379805 ...
# INFO:flwr:app_fit: metrics_distributed {'average_metrics': [(1, {'valid_mape': 8822.502764423078, 'valid_mae': 8822.502764423078, 'valid_rmse': 8840.326953125}), (2, {'valid_mape': 8679.481265024038, 'valid_mae': 8679.481265024038, 'valid_rmse': 8697.940414663462}), (3, {'valid_mape': 8569.587890625, 'valid_mae': 8569.587890625, 'valid_rmse': 8587.326292067308}), (4, {'valid_mape': 8438.65389873798, 'valid_mae': 8438.65389873798, 'valid_rmse': 8457.14178936298}), (5, {'valid_mape': 8339.997573617788, 'valid_mae': 8339.997573617788, 'valid_rmse': 8358.468592247596}), (6, {'valid_mape': 8225.562545072115, 'valid_mae': 8225.562545072115, 'valid_rmse': 8244.745057091346}), (7, {'valid_mape': 8153.0390474759615, 'valid_mae': 8153.0390474759615, 'valid_rmse': 8171.637447415866}), (8, {'valid_mape': 8062.055003004808, 'valid_mae': 8062.055003004808, 'valid_rmse': 8081.7839918870195}), (9, {'valid_mape': 8008.872160456731, 'valid_mae': 8008.872160456731, 'valid_rmse': 8028.708255709134}), (10, {'valid_mape': 7921.547934194711, 'valid_mae': 7921.547934194711, 'valid_rmse': 7942.157677283654})], 'client_metrics': [(1, {'valid_mape': [8789.794996995191, 8827.326923076924, 8830.306114783654, 8819.991962139424, 8845.093825120191], 'valid_mae': [8789.794996995191, 8827.326923076924, 8830.306114783654, 8819.991962139424, 8845.093825120191], 'valid_rmse': [8808.390700120191, 8844.954552283654, 8848.101712740385, 8837.99676983173, 8862.191030649039], 'examples': [208, 208, 208, 208, 208]}), (2, {'valid_mape': [8681.582106370191, 8698.33135516827, 8649.2744140625, 8696.072490985576, 8672.145958533654], 'valid_mae': [8681.582106370191, 8698.33135516827, 8649.2744140625, 8696.072490985576, 8672.145958533654], 'valid_rmse': [8700.035606971154, 8715.54169170673, 8669.963266225961, 8714.574368990385, 8689.587139423076], 'examples': [208, 208, 208, 208, 208]}), (3, {'valid_mape': [8608.43622295673, 8565.724684495191, 8555.892953725961, 8543.504281850961, 8574.381310096154], 'valid_mae': [8608.43622295673, 8565.724684495191, 8555.892953725961, 8543.504281850961, 8574.381310096154], 'valid_rmse': [8625.41669170673, 8583.699143629809, 8575.371619591346, 8561.000901442309, 8591.143103966346], 'examples': [208, 208, 208, 208, 208]}), (4, {'valid_mape': [8439.398813100961, 8440.654296875, 8487.1982421875, 8414.940091646635, 8411.078049879809], 'valid_mae': [8439.398813100961, 8440.654296875, 8487.1982421875, 8414.940091646635, 8411.078049879809], 'valid_rmse': [8458.746243990385, 8459.055588942309, 8505.30243389423, 8432.92333984375, 8429.68134014423], 'examples': [208, 208, 208, 208, 208]}), (5, {'valid_mape': [8293.300368088941, 8341.05829326923, 8321.608849158654, 8385.367412860576, 8358.652944711539], 'valid_mae': [8293.300368088941, 8341.05829326923, 8321.608849158654, 8385.367412860576, 8358.652944711539], 'valid_rmse': [8315.7275390625, 8358.485501802885, 8340.357797475961, 8402.843299278846, 8374.928823617789], 'examples': [208, 208, 208, 208, 208]}), (6, {'valid_mape': [8188.0154371995195, 8222.440054086539, 8222.74004657452, 8234.109637920674, 8260.507549579326], 'valid_mae': [8188.0154371995195, 8222.440054086539, 8222.74004657452, 8234.109637920674, 8260.507549579326], 'valid_rmse': [8209.862454927885, 8242.134652944711, 8240.651254507211, 8252.532827524039, 8278.544095552885], 'examples': [208, 208, 208, 208, 208]}), (7, {'valid_mape': [8127.845365084135, 8169.417743389423, 8134.768667367788, 8161.282752403846, 8171.880709134615], 'valid_mae': [8127.845365084135, 8169.417743389423, 8134.768667367788, 8161.282752403846, 8171.880709134615], 'valid_rmse': [8147.169546274038, 8188.95263671875, 8153.504544771635, 8179.4753981370195, 8189.085111177885], 'examples': [208, 208, 208, 208, 208]}), (8, {'valid_mape': [8030.912259615385, 8067.811636117788, 8066.0732421875, 8090.463040865385, 8055.0148362379805], 'valid_mae': [8030.912259615385, 8067.811636117788, 8066.0732421875, 8090.463040865385, 8055.0148362379805], 'valid_rmse': [8053.775615985577, 80 ...
# INFO flwr 2023-04-25 04:07:05,257 | app.py:221 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2023-04-25 04:07:05,261 | app.py:222 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# (launch_and_evaluate pid=9285) Eval RMSE: 8581.6318359375: 12
# (launch_and_evaluate pid=9746) Eval RMSE: 8608.129801432291: 12

# %%
# history of each client for training
flower_history.metrics_distributed_fit

# history of each client for validation
flower_history.metrics_distributed

x, y = [], []
for average_metrics in flower_history.metrics_distributed['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['valid_rmse'])


plt.figure(figsize=(20, 12), dpi = 150)

plt.plot(x, y, label='Average RMSE in each round c = '+str(NUM_CLIENTS))
plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE', fontsize=20)
#plt.show()
plt.legend(fontsize=14)
plt.savefig(f'average_val_RMSE_rounds_{NUM_ROUNDS}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

x =  []
y = [[] for i in flower_history.metrics_distributed['client_metrics'][0][1]['valid_rmse']]
for client_metrics in flower_history.metrics_distributed['client_metrics']:
    x.append(client_metrics[0])
    for idx, client_loss in enumerate(client_metrics[1]['valid_rmse']):
        y[idx].append(client_loss)


plt.figure(figsize=(20, 12), dpi = 150)
for client_num, loss_ in enumerate(y):
    plt.plot(x, loss_, label='Val RMSE of c: '+str(client_num))
plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE (individual client), c = '+str(NUM_CLIENTS))
#plt.show()
plt.legend(fontsize=14)
plt.savefig(f'individual_val_average_RMSE_rounds_{NUM_ROUNDS}_c_{NUM_CLIENTS}.png', bbox_inches='tight')



plt.figure(figsize=(20, 12), dpi = 150)
for client_num, loss_ in enumerate(y):
    plt.plot(x, loss_)
plt.xlabel('Rounds', fontsize=16)
plt.ylabel('RMSE', fontsize=16)
plt.legend()
plt.title('Validation Curve for RMSE (individual client), c = '+str(NUM_CLIENTS))
#plt.show()
plt.legend(fontsize=14)
plt.savefig(f'individual_val_average_RMSE_rounds_{NUM_ROUNDS}_c_{NUM_CLIENTS}_no_legend.png', bbox_inches='tight')

x, y = [], []
for average_metrics in flower_history.metrics_distributed_fit['average_metrics']:
    x.append(average_metrics[0])
    y.append(average_metrics[1]['average loss'])

plt.figure(figsize=(20, 12), dpi = 150)

plt.plot(x, y, label='Average loss in each round c = '+str(NUM_CLIENTS))
plt.xlabel('Rounds', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend()
plt.title('Training Curve for Loss', fontsize=20)
plt.legend(fontsize=14)
#plt.show()
plt.savefig(f'average_training_loss_rounds_{NUM_ROUNDS}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

x =  []
y = [[] for i in flower_history.metrics_distributed_fit['client_metrics'][0][1]['loss']]
for client_metrics in flower_history.metrics_distributed_fit['client_metrics']:
    x.append(client_metrics[0])
    for idx, client_loss in enumerate(client_metrics[1]['loss']):
        y[idx].append(client_loss)

plt.figure(figsize=(20, 12))
for client_num, loss_ in enumerate(y):
    plt.plot(x, loss_, label='Training Loss of client: '+str(client_num))
plt.xlabel('Rounds', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend()
plt.title('Training Curve for Loss (individual client) c = '+str(NUM_CLIENTS))
#plt.show()
plt.savefig(f'individual_average_training_loss_rounds_{NUM_ROUNDS}_c_{NUM_CLIENTS}.png', bbox_inches='tight')

plt.figure(figsize=(20, 12))
for client_num, loss_ in enumerate(y):
    plt.plot(x, loss_)
plt.xlabel('Rounds', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend()
plt.title('Training Curve for Loss (individual client) c = '+str(NUM_CLIENTS))
#plt.show()
plt.savefig(f'individual_average_training_loss_rounds_{NUM_ROUNDS}_c_{NUM_CLIENTS}_no_label.png', bbox_inches='tight')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
with open('flower_history.pkl', 'wb') as f:
    pickle.dump(flower_history, f)

with open('flower_history.pkl', 'rb') as f:
    history = pickle.load(f)


x, y = [], []
print(history.metrics_distributed['loss'])
for average_metrics in history.metrics_distributed['loss']:
    x.append(average_metrics[0])
    y.append(average_metrics[1])


plt.figure(figsize=(12, 6))

plt.plot(x, y, label='Average loss')
plt.xlabel('Rounds')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-4e56bc236657> in <cell line: 9>()
#       7
#       8 x, y = [], []
# ----> 9 print(history.metrics_distributed['loss'])
#      10 for average_metrics in history.metrics_distributed['loss']:
#      11     x.append(average_metrics[0])
#
# KeyError: 'loss'
